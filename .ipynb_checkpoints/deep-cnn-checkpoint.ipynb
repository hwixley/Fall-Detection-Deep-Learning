# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import _LRScheduler
import torch.utils.data as data
from torch.utils.data import TensorDataset, DataLoader

import torchvision.transforms as transforms
import torchvision.datasets as datasets

from sklearn import decomposition
from sklearn import manifold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from tqdm.notebook import tqdm, trange
import matplotlib.pyplot as plt
import numpy as np

import copy
import random
import time
import os

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
db = "16.1"
features = "polar"
lag = "0"
model_save_dir = os.getcwd() + f"/ml-models/db{db}/{features}-lag{lag}/"

# %%
def loadNpy(filename):
    with open(os.getcwd() + "/train-val-test/"+ filename, "rb") as f: return np.load(f)

db = f"db{db}/window-size-10/lag{lag}/{features}-features/"
data_type = ""

# %%
DIR = os.getcwd() + "/train-val-test/" + db

# %%
def npy_to_tensor(data, l=False):
    if not l:
        data = torch.from_numpy(data).float()
    else:
        data = torch.from_numpy(data).type(torch.LongTensor)
    return data

# %%
X_train, X_val, X_test = loadNpy(db + f"X_train.npy"), loadNpy(db + f"X_val.npy"), loadNpy(db + f"X_test.npy")
y_train, y_val, y_test = loadNpy(db + f"y{data_type}_train.npy"), loadNpy(db + f"y{data_type}_val.npy"), loadNpy(db + f"y{data_type}_test.npy")

# %%
X_train, X_val, X_test = npy_to_tensor(X_train), npy_to_tensor(X_val), npy_to_tensor(X_test)
y_train, y_val, y_test = npy_to_tensor(y_train, 1), npy_to_tensor(y_val, 1), npy_to_tensor(y_test, 1)

# %%
X_train, X_val, X_test = loadNpy(db + f"us-X_train.npy"), loadNpy(db + f"us-X_val.npy"), loadNpy(db + f"us-X_test.npy")
y_train, y_val, y_test = loadNpy(db + f"y{data_type}_train.npy"), loadNpy(db + f"y{data_type}_val.npy"), loadNpy(db + f"y{data_type}_test.npy")

# %%
X_train, X_val, X_test = npy_to_tensor(X_train), npy_to_tensor(X_val), npy_to_tensor(X_test)
y_train, y_val, y_test = npy_to_tensor(y_train, 1), npy_to_tensor(y_val, 1), npy_to_tensor(y_test, 1)

# %%
batch_size = 128

# %%
train_dataset = TensorDataset(X_train, y_train)

val_dataset = TensorDataset(X_val, y_val)

test_dataset = TensorDataset(X_test, y_test)

# Data loader
train_iterator = DataLoader(dataset=train_dataset,batch_size=batch_size,shuffle=False)

val_iterator = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)

test_iterator = DataLoader(dataset=test_dataset, batch_size=batch_size,shuffle=False)

# %%
torch.save(train_dataset, DIR + "train-dataset")
torch.save(val_dataset, DIR + "val-dataset")
torch.save(test_dataset, DIR + "test-dataset")

# %%
X_train.shape
# Out:
# torch.Size([37781, 1, 28, 28])

# %%
X_val.shape
# Out:
# torch.Size([12594, 784])

# %%
X_test.shape
# Out:
# torch.Size([12594, 784])

# %%
input_size = val_iterator

# %%
X_train.dtype
# Out:
# torch.float32

# %% [markdown]
# # Fully Connected NN

# %%
input_size = 784
h1_size = 700
h2_size = 800
h3_size = 900
h4_size = 800
h5_size = 700
num_classes = 2
num_epochs = 1000
batch_size = 64
learning_rate = 0.001

# %%
# Fully connected neural network with one hidden layer
class NeuralNet(nn.Module):
    def __init__(self, input_size, num_classes):
        super(NeuralNet, self).__init__()
        self.fc1 = nn.Linear(input_size, h1_size) 
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(h1_size, h2_size)
        self.relu2 = nn.ReLU()
        #self.drop1 = nn.Dropout(p=0.2)
        self.fc3 = nn.Linear(h2_size, h3_size)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(h3_size, h4_size)
        self.relu4 = nn.ReLU()
        #self.drop2 = nn.Dropout(p=0.2)
        self.fc5 = nn.Linear(h4_size, h5_size)
        self.relu5 = nn.ReLU()
        self.fc6 = nn.Linear(h5_size, num_classes)
    
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu1(out)
        out = self.fc2(out)
        out = self.relu2(out)
        #out = self.drop1(out)
        out = self.fc3(out)
        out = self.relu3(out)
        out = self.fc4(out)
        out = self.relu4(out)
        #out = self.drop2(out)
        out = self.fc5(out)
        out = self.relu5(out)
        out = self.fc6(out)
        return out

# %%
nn_model = NeuralNet(input_size, num_classes).to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(nn_model.parameters(), lr=learning_rate)

# %%
nn_epochs = {}

# Train the model
total_step = len(train_iterator)
for epoch in tqdm(range(num_epochs)):
    for i, (images, labels) in enumerate(train_iterator):  
        # Move tensors to the configured device
        images = images.to(device)
        labels = labels.to(device)
        
        # Forward pass
        #print(images.shape)
        outputs = nn_model(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #print(i)

    print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
           .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
    nn_epochs[epoch] = {"loss": loss.item(), "train": eval_nn(nn_model, train_iterator), 
                 "val": eval_nn(nn_model, val_iterator), "test": eval_nn(nn_model, test_iterator)}
    nn_model.train()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch [1/1000], Step [591/591], Loss: 0.8452
# Accuracy of the network on the 37781 test images: 83.1343797146714 %
# Accuracy of the network on the 12594 test images: 83.03160235032556 %
# Accuracy of the network on the 12594 test images: 83.01572177227251 %
# Epoch [2/1000], Step [591/591], Loss: 0.6889
# Accuracy of the network on the 37781 test images: 83.1343797146714 %
# Accuracy of the network on the 12594 test images: 83.03160235032556 %
# Accuracy of the network on the 12594 test images: 83.01572177227251 %
# Epoch [3/1000], Step [591/591], Loss: 0.6103
# Accuracy of the network on the 37781 test images: 83.1343797146714 %
# Accuracy of the network on the 12594 test images: 83.03160235032556 %
# Accuracy of the network on the 12594 test images: 83.01572177227251 %
# Epoch [4/1000], Step [591/591], Loss: 0.6733
# Accuracy of the network on the 37781 test images: 83.1343797146714 %
# Accuracy of the network on the 12594 test images: 83.03160235032556 %
# Accuracy of the network on the 12594 test images: 83.01572177227251 %
# Epoch [5/1000], Step [591/591], Loss: 0.6384
# Accuracy of the network on the 37781 test images: 83.1343797146714 %
# Accuracy of the network on the 12594 test images: 83.03160235032556 %
# Accuracy of the network on the 12594 test images: 83.01572177227251 %
# Epoch [6/1000], Step [591/591], Loss: 0.5813
# Accuracy of the network on the 37781 test images: 83.53405150737143 %
# Accuracy of the network on the 12594 test images: 83.28569159917421 %
# Accuracy of the network on the 12594 test images: 83.40479593457202 %
# Epoch [7/1000], Step [591/591], Loss: 0.5346
# Accuracy of the network on the 37781 test images: 83.63992482994098 %
# Accuracy of the network on the 12594 test images: 83.60330316023503 %
# Accuracy of the network on the 12594 test images: 83.50007940289026 %
# Epoch [8/1000], Step [591/591], Loss: 0.6995
# Accuracy of the network on the 37781 test images: 83.16084804531378 %
# Accuracy of the network on the 12594 test images: 82.80133396855645 %
# Accuracy of the network on the 12594 test images: 82.90455772590123 %
# Epoch [9/1000], Step [591/591], Loss: 0.6335
# Accuracy of the network on the 37781 test images: 83.58434133559196 %
# Accuracy of the network on the 12594 test images: 83.25393044306813 %
# Accuracy of the network on the 12594 test images: 83.3571542004129 %
# Epoch [10/1000], Step [591/591], Loss: 0.5069
# Accuracy of the network on the 37781 test images: 84.0448902887695 %
# Accuracy of the network on the 12594 test images: 83.79387009687153 %
# Accuracy of the network on the 12594 test images: 83.84945212005717 %
# Epoch [11/1000], Step [591/591], Loss: 0.5206
# Accuracy of the network on the 37781 test images: 84.09518011699002 %
# Accuracy of the network on the 12594 test images: 84.00825790058758 %
# Accuracy of the network on the 12594 test images: 83.92091472129586 %
# Epoch [12/1000], Step [591/591], Loss: 0.5051
# Accuracy of the network on the 37781 test images: 83.18202270982769 %
# Accuracy of the network on the 12594 test images: 83.07924408448467 %
# Accuracy of the network on the 12594 test images: 83.0554232174051 %
# Epoch [13/1000], Step [591/591], Loss: 0.5429
# Accuracy of the network on the 37781 test images: 83.99989412667743 %
# Accuracy of the network on the 12594 test images: 83.84945212005717 %
# Accuracy of the network on the 12594 test images: 83.90503414324282 %
# Epoch [14/1000], Step [591/591], Loss: 0.7563
# Accuracy of the network on the 37781 test images: 78.01275773536963 %
# Accuracy of the network on the 12594 test images: 78.04510084167063 %
# Accuracy of the network on the 12594 test images: 77.71160870255677 %
# Epoch [15/1000], Step [591/591], Loss: 0.5231
# Accuracy of the network on the 37781 test images: 84.03430295651253 %
# Accuracy of the network on the 12594 test images: 83.7065269175798 %
# Accuracy of the network on the 12594 test images: 83.84151183103064 %
# Epoch [16/1000], Step [591/591], Loss: 0.5319
# Accuracy of the network on the 37781 test images: 84.24869643471587 %
# Accuracy of the network on the 12594 test images: 84.0956010798793 %
# Accuracy of the network on the 12594 test images: 84.12736223598539 %
# Epoch [17/1000], Step [591/591], Loss: 0.5245
# Accuracy of the network on the 37781 test images: 84.01048145893438 %
# Accuracy of the network on the 12594 test images: 83.7065269175798 %
# Accuracy of the network on the 12594 test images: 83.71446720660632 %
# Epoch [18/1000], Step [591/591], Loss: 0.6960
# Accuracy of the network on the 37781 test images: 83.16349487837802 %
# Accuracy of the network on the 12594 test images: 82.79339367952994 %
# Accuracy of the network on the 12594 test images: 83.02366206129904 %
# Epoch [19/1000], Step [591/591], Loss: 0.6354
# Accuracy of the network on the 37781 test images: 83.60816283317011 %
# Accuracy of the network on the 12594 test images: 83.28569159917421 %
# Accuracy of the network on the 12594 test images: 83.46037795775766 %
# Epoch [20/1000], Step [591/591], Loss: 0.5085
# Accuracy of the network on the 37781 test images: 84.29369259680792 %
# Accuracy of the network on the 12594 test images: 84.15912339209147 %
# Accuracy of the network on the 12594 test images: 84.06383992377323 %
# Epoch [21/1000], Step [591/591], Loss: 0.5316
# Accuracy of the network on the 37781 test images: 84.30163309600063 %
# Accuracy of the network on the 12594 test images: 84.11148165793234 %
# Accuracy of the network on the 12594 test images: 84.07972050182627 %
# Epoch [22/1000], Step [591/591], Loss: 0.4576
# Accuracy of the network on the 37781 test images: 84.44720891453376 %
# Accuracy of the network on the 12594 test images: 84.15118310306495 %
#
# Accuracy of the network on the 12594 test images: 84.4370335080197 %
# Epoch [990/1000], Step [591/591], Loss: 0.4575
# Accuracy of the network on the 37781 test images: 84.66424922580133 %
# Accuracy of the network on the 12594 test images: 84.10354136890582 %
# Accuracy of the network on the 12594 test images: 84.4370335080197 %
# Epoch [991/1000], Step [591/591], Loss: 0.4340
# Accuracy of the network on the 37781 test images: 84.76218204917816 %
# Accuracy of the network on the 12594 test images: 84.26234714943624 %
# Accuracy of the network on the 12594 test images: 84.5561378434175 %
# Epoch [992/1000], Step [591/591], Loss: 0.4320
# Accuracy of the network on the 37781 test images: 84.75953521611392 %
# Accuracy of the network on the 12594 test images: 84.19088454819756 %
# Accuracy of the network on the 12594 test images: 84.45291408607274 %
# Epoch [993/1000], Step [591/591], Loss: 0.4497
# Accuracy of the network on the 37781 test images: 84.60601889838807 %
# Accuracy of the network on the 12594 test images: 84.08766079085278 %
# Accuracy of the network on the 12594 test images: 84.33380975067493 %
# Epoch [994/1000], Step [591/591], Loss: 0.4355
# Accuracy of the network on the 37781 test images: 84.62984039596623 %
# Accuracy of the network on the 12594 test images: 84.03207876766714 %
# Accuracy of the network on the 12594 test images: 84.48467524217881 %
# Epoch [995/1000], Step [591/591], Loss: 0.4339
# Accuracy of the network on the 37781 test images: 84.80188454514173 %
# Accuracy of the network on the 12594 test images: 84.19088454819756 %
# Accuracy of the network on the 12594 test images: 84.53231697633794 %
# Epoch [996/1000], Step [591/591], Loss: 0.4418
# Accuracy of the network on the 37781 test images: 84.71189222095762 %
# Accuracy of the network on the 12594 test images: 84.07972050182627 %
# Accuracy of the network on the 12594 test images: 84.44497379704622 %
# Epoch [997/1000], Step [591/591], Loss: 0.4283
# Accuracy of the network on the 37781 test images: 84.7860035467563 %
# Accuracy of the network on the 12594 test images: 84.15912339209147 %
# Accuracy of the network on the 12594 test images: 84.41321264094013 %
# Epoch [998/1000], Step [591/591], Loss: 0.4259
# Accuracy of the network on the 37781 test images: 84.79129721288479 %
# Accuracy of the network on the 12594 test images: 84.21470541527711 %
# Accuracy of the network on the 12594 test images: 84.42909321899317 %
# Epoch [999/1000], Step [591/591], Loss: 0.4321
# Accuracy of the network on the 37781 test images: 84.72512638627882 %
# Accuracy of the network on the 12594 test images: 84.03207876766714 %
# Accuracy of the network on the 12594 test images: 84.39733206288709 %
# Epoch [1000/1000], Step [591/591], Loss: 0.4314
# Accuracy of the network on the 37781 test images: 84.83894020804108 %
# Accuracy of the network on the 12594 test images: 84.2464665713832 %
# Accuracy of the network on the 12594 test images: 84.5561378434175 %

# %%
def eval_nn(mod, data):
    preds = []
    actual = []
    
    shape = data.dataset.tensors[0].shape[1:]
    
    mod.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in data:
            images = images.to(device)
            labels = labels.to(device)
            outputs = mod(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            preds.append(predicted)
            actual.append(labels)

        print(f'Accuracy of the network on the {total} test images: {100 * correct / total} %')
    return preds, actual, correct/total

# %%
# Test the model
# In test phase, we don't need to compute gradients (for memory efficiency)
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_iterator:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print(f'Accuracy of the network on the {total} test images: {100 * correct / total} %')

# %%
def eval_rnn(mod, data):
    preds = []
    actual = []
    
    shape = data.dataset.tensors[0].shape[1:]
    
    mod.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in data:
            images = images.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.to(device)
            outputs = mod(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            preds.append(predicted)
            actual.append(labels)

        print(f'Accuracy of the model on the {total} samples: {100 * correct / total} %')
    return preds, actual, correct/total

# %%
from torchmetrics import ROC

def eval_cnn(data):
    
    cnn.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        pred_ys = []
        labs = []
        for images, labels in loaders[data]:
            images = images.to(device)
            labels = labels.to(device)
            test_output, last_layer = cnn(images)
            pred_y = torch.max(test_output, 1)[1].data.squeeze()
            pred_ys = pred_ys + test_output.flatten().tolist()
            labs = labs + labels.tolist()
            total += len(labels)
            correct += (pred_y == labels).sum().item()
            pass
        print(f'{data} Accuracy of the model on the {total} {data} images: %.3f' % (correct/total))
        return pred_ys, labs, correct/total
    pass

# %% [markdown]
# # CNN

# %%
loaders = {
    'train': train_iterator,
    'val': val_iterator,
    'test': test_iterator
}

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(         
            nn.Conv2d(
                in_channels=1,              
                out_channels=16,            
                kernel_size=5,              
                stride=1,                   
                padding=2,                  
            ),
            #nn.BatchNorm2d(16),
            nn.ReLU(),                      
            nn.MaxPool2d(kernel_size=2),    
        ).to(device)
        self.conv2 = nn.Sequential(         
            nn.Conv2d(16, 32, 5, 1, 2),
            #nn.BatchNorm2d(32),
            nn.ReLU(),                      
            nn.MaxPool2d(2),                
        ).to(device)
        self.conv3 = nn.Sequential(         
            nn.Conv2d(32, 64, 5, 1, 2),
            #nn.BatchNorm2d(64),
            nn.ReLU(),
        ).to(device)
        # fully connected layer, output 10 classes
        self.out = nn.Linear(64*7*7, 2).to(device)
    def forward(self, x):
        x = x.to(device)
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        # flatten the output of conv2 to (batch_size, 32 * 7 * 7)
        x = x.view(x.size(0), -1)
        #print(x.shape)
        output = self.out(x)
        return output, x    # return x for visualization

# %%
cnn = CNN()
print(cnn)
# Out:
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(6, 6), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#   )
#   (out): Linear(in_features=3136, out_features=2, bias=True)
# )

# %%
loss_func = nn.CrossEntropyLoss()   
loss_func
# Out:
# CrossEntropyLoss()

# %%
optimizer = optim.Adam(cnn.parameters(), lr = 0.001)   
optimizer
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )

# %%
from torch.autograd import Variable

num_epochs = 1000
cnn_epochs = {}

def train(num_epochs, cnn, loaders):
    
    cnn.train()
        
    # Train the model
    total_step = len(loaders['train'])
        
    for epoch in range(num_epochs):
        for i, (images, labels) in enumerate(loaders['train']):
            
            images = images.to(device)
            labels = labels.to(device)
            # gives batch data, normalize x when iterate train_loader
            b_x = Variable(images)   # batch x
            b_y = Variable(labels)   # batch y
            output = cnn(b_x)[0]               
            loss = loss_func(output, b_y)
            
            # clear gradients for this training step   
            optimizer.zero_grad()           
            
            # backpropagation, compute gradients 
            loss.backward()    
            # apply gradients             
            optimizer.step()                
            
            if (i+1) % 100 == 0:
                print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'.format(epoch + 1, num_epochs, i + 1, total_step, loss.item()))
                cnn_epochs[epoch] = {"loss": loss.item(), "train": eval_cnn("train"), 
                             "val": eval_cnn("val"), "test": eval_cnn("test")}
                cnn.train()
                pass
        pass
    pass

train(num_epochs, cnn, loaders)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_81939/4054680238.py in <module>
#      39     pass
#      40
# ---> 41 train(num_epochs, cnn, loaders)
#
# /tmp/ipykernel_81939/4054680238.py in train(num_epochs, cnn, loaders)
#      19             b_x = Variable(images)   # batch x
#      20             b_y = Variable(labels)   # batch y
# ---> 21             output = cnn(b_x)[0]
#      22             loss = loss_func(output, b_y)
#      23
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /tmp/ipykernel_81939/3437749517.py in forward(self, x)
#      35         x = x.view(x.size(0), -1)
#      36         #print(x.shape)
# ---> 37         output = self.out(x)
#      38         return output, x    # return x for visualization
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1942     if has_torch_function_variadic(input, weight, bias):
#    1943         return handle_torch_function(linear, (input, weight, bias), input, weight, bias=bias)
# -> 1944     return torch._C._nn.linear(input, weight, bias)
#    1945
#    1946
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (128x2304 and 3136x2)

# %%
eval_cnn("val")
eval_cnn("test")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_94475/2557412106.py in <module>
# ----> 1 eval_cnn("val")
#       2 eval_cnn("test")
#
# /tmp/ipykernel_94475/2928619253.py in eval_cnn(data)
#      12             images = images.to(device)
#      13             labels = labels.to(device)
# ---> 14             test_output, last_layer = cnn(images)
#      15             pred_y = torch.max(test_output, 1)[1].data.squeeze()
#      16             pred_ys = pred_ys + test_output.flatten().tolist()
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /tmp/ipykernel_94475/3403479315.py in forward(self, x)
#      34         x = self.conv2(x)
#      35         x = self.conv3(x)
# ---> 36         x = self.conv4(x)
#      37         # flatten the output of conv2 to (batch_size, 32 * 7 * 7)
#      38         x = x.view(x.size(0), -1)
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     445
#     446     def forward(self, input: Tensor) -> Tensor:
# --> 447         return self._conv_forward(input, self.weight, self.bias)
#     448
#     449 class Conv3d(_ConvNd):
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     441                             weight, bias, self.stride,
#     442                             _pair(0), self.dilation, self.groups)
# --> 443         return F.conv2d(input, weight, bias, self.stride,
#     444                         self.padding, self.dilation, self.groups)
#     445
#
# RuntimeError: Given groups=1, weight of size [32, 16, 5, 5], expected input[128, 64, 3, 3] to have 16 channels, but got 64 channels instead

# %%
roc = ROC(num_classes=2)
fpr, tpr, thresholds = roc(torch.FloatTensor(pred_ys), torch.FloatTensor(labs))

# %%
from torchviz import make_dot

dum_input = torch.ones(1,1,28,28)
a, b = cnn(dum_input)
make_dot(a, params=dict(cnn.named_parameters())).render(f"{model_save_dir}viz/cnn-{num_epochs}epochs-crossEnt-adamOpt",format="png")
# Out:
# '/home/hwixley/Documents/4th-Year/Honours-Project/localhost-data-preprocessing/ml-models/db16.1/polar-lag0/viz/cnn-1000epochs-crossEnt-adamOpt.png'

# %%
train = []
val = []
test = []
loss = []

for i in range(num_epochs):
    ep = cnn_epochs[i]
    train.append(ep["train"][2])
    val.append(ep["val"][2])
    test.append(ep["test"][2])
    loss.append(ep["loss"])

# %%
epochs = np.arange(0,num_epochs,1)

plt.plot(epochs, train, c="r", lw=0.7, label="Train")
plt.plot(epochs, val, c="b", lw=0.7, label="Validation")
plt.plot(epochs, test, c="g", lw=0.7, label="Test")
plt.grid(True)
plt.legend(loc="upper left")
plt.title("CNN (polar features, lag 0) - Epoch vs. Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch #")
plt.yticks(np.arange(0.8,1.01,0.1))
# Out:
# ([<matplotlib.axis.YTick at 0x7f1d4ef0cf10>,
#   <matplotlib.axis.YTick at 0x7f1d4ef0c970>,
#   <matplotlib.axis.YTick at 0x7f1d4fa54880>],
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %% [markdown]
# ## CORE ML

# %% [markdown]
# ## ONNX

# %%
import onnx

# %%
cnn.eval()
dummy_input = torch.randn(1, 1, 28, 28)
input_names = [ "actual_input" ]
output_names = [ "output" ]
model = cnn

# %%
torch.onnx.export(model, 
                  dummy_input,
                  "polar-window10-lag0-cnn.onnx",
                  verbose=False,
                  input_names=input_names,
                  output_names=output_names,
                  export_params=True,
                  )

# %% [markdown]
# # LSTM

# %%
# Hyper-parameters
sequence_length = 28
input_size = 28
hidden_size = 128
num_layers = 2
num_classes = 2
batch_size = 128
num_epochs = 1000
learning_rate = 0.01

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x):
        # Set initial hidden and cell states 
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) 
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        
        # Forward propagate LSTM
        out, _ = self.lstm(x, (h0, c0))  # out: tensor of shape (batch_size, seq_length, hidden_size)
        
        # Decode the hidden state of the last time step
        out = self.fc(out[:, -1, :])
        return out

# %%
epochs = {}

# %%
model = RNN(input_size, hidden_size, num_layers, num_classes).to(device)


# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Train the model
total_step = len(train_iterator)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_iterator):
        images = images.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
            epochs[epoch] = {"loss": loss.item(), "train": eval_rnn(model, train_iterator), 
                             "val": eval_rnn(model, val_iterator), "test": eval_rnn(model, test_iterator)} 
            
            model.train()
# Out:
# Epoch [1/1000], Step [100/300], Loss: 0.4202
# Accuracy of the model on the 38311 samples: 83.26068231056355 %
# Accuracy of the model on the 12771 samples: 83.58781614595568 %
# Accuracy of the model on the 12771 samples: 83.25111580925534 %
# Epoch [1/1000], Step [200/300], Loss: 0.3879
# Accuracy of the model on the 38311 samples: 83.26068231056355 %
# Accuracy of the model on the 12771 samples: 83.58781614595568 %
# Accuracy of the model on the 12771 samples: 83.25111580925534 %
# Epoch [1/1000], Step [300/300], Loss: 0.3471
# Accuracy of the model on the 38311 samples: 83.26068231056355 %
# Accuracy of the model on the 12771 samples: 83.58781614595568 %
# Accuracy of the model on the 12771 samples: 83.25111580925534 %
# Epoch [2/1000], Step [100/300], Loss: 0.3362
# Accuracy of the model on the 38311 samples: 83.26068231056355 %
# Accuracy of the model on the 12771 samples: 83.58781614595568 %
# Accuracy of the model on the 12771 samples: 83.25111580925534 %
# Epoch [2/1000], Step [200/300], Loss: 0.3621
# Accuracy of the model on the 38311 samples: 83.26329252695048 %
# Accuracy of the model on the 12771 samples: 83.58781614595568 %
# Accuracy of the model on the 12771 samples: 83.25111580925534 %
# Epoch [2/1000], Step [300/300], Loss: 0.2381
# Accuracy of the model on the 38311 samples: 84.12988436741406 %
# Accuracy of the model on the 12771 samples: 84.41782162712396 %
# Accuracy of the model on the 12771 samples: 83.94017696343278 %
# Epoch [3/1000], Step [100/300], Loss: 0.2629
# Accuracy of the model on the 38311 samples: 84.47704314687688 %
# Accuracy of the model on the 12771 samples: 84.69188004071725 %
# Accuracy of the model on the 12771 samples: 84.54310547333803 %
# Epoch [3/1000], Step [200/300], Loss: 0.3508
# Accuracy of the model on the 38311 samples: 84.91033906710867 %
# Accuracy of the model on the 12771 samples: 84.7858429253778 %
# Accuracy of the model on the 12771 samples: 84.91895701198027 %
# Epoch [3/1000], Step [300/300], Loss: 0.2315
# Accuracy of the model on the 38311 samples: 84.90772885072172 %
# Accuracy of the model on the 12771 samples: 84.71537076188238 %
# Accuracy of the model on the 12771 samples: 84.91895701198027 %
# Epoch [4/1000], Step [100/300], Loss: 0.2843
# Accuracy of the model on the 38311 samples: 84.60494374983686 %
# Accuracy of the model on the 12771 samples: 84.8641453292616 %
# Accuracy of the model on the 12771 samples: 84.7936731657662 %
# Epoch [4/1000], Step [200/300], Loss: 0.3403
# Accuracy of the model on the 38311 samples: 85.18180157135026 %
# Accuracy of the model on the 12771 samples: 85.14603398324329 %
# Accuracy of the model on the 12771 samples: 85.35745047372954 %
# Epoch [4/1000], Step [300/300], Loss: 0.2311
# Accuracy of the model on the 38311 samples: 85.12698702722456 %
# Accuracy of the model on the 12771 samples: 84.99725941586406 %
# Accuracy of the model on the 12771 samples: 85.04424085819434 %
# Epoch [5/1000], Step [100/300], Loss: 0.2618
# Accuracy of the model on the 38311 samples: 85.1844117877372 %
# Accuracy of the model on the 12771 samples: 85.12254326207814 %
# Accuracy of the model on the 12771 samples: 85.23216662751547 %
# Epoch [5/1000], Step [200/300], Loss: 0.3238
# Accuracy of the model on the 38311 samples: 85.17919135496332 %
# Accuracy of the model on the 12771 samples: 85.2948085506225 %
# Accuracy of the model on the 12771 samples: 85.2556573486806 %
# Epoch [5/1000], Step [300/300], Loss: 0.2447
# Accuracy of the model on the 38311 samples: 85.39322909869229 %
# Accuracy of the model on the 12771 samples: 85.30263879101088 %
# Accuracy of the model on the 12771 samples: 85.44358311800173 %
# Epoch [6/1000], Step [100/300], Loss: 0.2803
# Accuracy of the model on the 38311 samples: 84.85552452298296 %
# Accuracy of the model on the 12771 samples: 85.21650614673871 %
# Accuracy of the model on the 12771 samples: 84.97376869469893 %
# Epoch [6/1000], Step [200/300], Loss: 0.3444
# Accuracy of the model on the 38311 samples: 85.72211636344653 %
# Accuracy of the model on the 12771 samples: 85.8037741758672 %
# Accuracy of the model on the 12771 samples: 85.78811369509044 %
# Epoch [6/1000], Step [300/300], Loss: 0.2168
# Accuracy of the model on the 38311 samples: 85.85262718279346 %
# Accuracy of the model on the 12771 samples: 85.82726489703234 %
# Accuracy of the model on the 12771 samples: 85.81160441625558 %
# Epoch [7/1000], Step [100/300], Loss: 0.2688
# Accuracy of the model on the 38311 samples: 85.5707238130041 %
# Accuracy of the model on the 12771 samples: 85.6080181661577 %
# Accuracy of the model on the 12771 samples: 85.38094119489469 %
# Epoch [7/1000], Step [200/300], Loss: 0.3311
# Accuracy of the model on the 38311 samples: 85.7612696092506 %
# Accuracy of the model on the 12771 samples: 86.25009787800485 %
# Accuracy of the model on the 12771 samples: 85.98386970479994 %
# Epoch [7/1000], Step [300/300], Loss: 0.2196
# Accuracy of the model on the 38311 samples: 85.32536347263188 %
# Accuracy of the model on the 12771 samples: 85.48273431994362 %
# Accuracy of the model on the 12771 samples: 85.06773157935949 %
# Epoch [8/1000], Step [100/300], Loss: 0.2652
# Accuracy of the model on the 38311 samples: 85.56028294745634 %
# Accuracy of the model on the 12771 samples: 85.71764153159502 %
# Accuracy of the model on the 12771 samples: 85.07556181974786 %
# Epoch [8/1000], Step [200/300], Loss: 0.3469
# Accuracy of the model on the 38311 samples: 86.02751168071833 %
# Accuracy of the model on the 12771 samples: 86.42236316654922 %
# Accuracy of the model on the 12771 samples: 86.18745595489781 %
# Epoch [8/1000], Step [300/300], Loss: 0.2079
# Accuracy of the model on the 38311 samples: 86.1345305525828 %
# Accuracy of the model on the 12771 samples: 86.11698379140239 %
# Accuracy of the model on the 12771 samples: 86.07000234907211 %
# Epoch [9/1000], Step [100/300], Loss: 0.2596
# Accuracy of the model on the 38311 samples: 85.71167549789878 %
# Accuracy of the model on the 12771 samples: 85.94471850285804 %
# Accuracy of the model on the 12771 samples: 85.54537624305067 %
# Epoch [9/1000], Step [200/300], Loss: 0.3347
# Accuracy of the model on the 38311 samples: 86.06927514290935 %
# Accuracy of the model on the 12771 samples: 86.5867982147052 %
# Accuracy of the model on the 12771 samples: 86.0778325894605 %
# Epoch [9/1000], Step [300/300], Loss: 0.2207
# Accuracy of the model on the 38311 samples: 85.97530735297956 %
# Accuracy of the model on the 12771 samples: 86.24226763761648 %
# Accuracy of the model on the 12771 samples: 86.10132331062563 %
# Epoch [10/1000], Step [100/300], Loss: 0.2588
# Accuracy of the model on the 38311 samples: 86.11103860510036 %
# Accuracy of the model on the 12771 samples: 86.33623052227703 %
# Accuracy of the model on the 12771 samples: 85.9995301855767 %
# Epoch [10/1000], Step [200/300], Loss: 0.3328
# Accuracy of the model on the 38311 samples: 86.05100362820077 %
# Accuracy of the model on the 12771 samples: 86.64944013781223 %
# Accuracy of the model on the 12771 samples: 86.07000234907211 %
# Epoch [10/1000], Step [300/300], Loss: 0.2102
# Accuracy of the model on the 38311 samples: 85.93876432356242 %
# Accuracy of the model on the 12771 samples: 86.04651162790698 %
# Accuracy of the model on the 12771 samples: 85.882076579751 %
# Epoch [11/1000], Step [100/300], Loss: 0.2646
# Accuracy of the model on the 38311 samples: 86.20500639503015 %
# Accuracy of the model on the 12771 samples: 86.51632605120977 %
# Accuracy of the model on the 12771 samples: 86.08566282984887 %
# Epoch [11/1000], Step [200/300], Loss: 0.3374
# Accuracy of the model on the 38311 samples: 86.27287202109055 %
# Accuracy of the model on the 12771 samples: 86.59462845509357 %
# Accuracy of the model on the 12771 samples: 85.9995301855767 %
# Epoch [11/1000], Step [300/300], Loss: 0.2170
# Accuracy of the model on the 38311 samples: 86.16324293283913 %
# Accuracy of the model on the 12771 samples: 86.22660715683972 %
# Accuracy of the model on the 12771 samples: 86.05434186829535 %
# Epoch [12/1000], Step [100/300], Loss: 0.2494
# Accuracy of the model on the 38311 samples: 86.34073764715095 %
# Accuracy of the model on the 12771 samples: 86.53198653198653 %
# Accuracy of the model on the 12771 samples: 86.17962571450944 %
# Epoch [12/1000], Step [200/300], Loss: 0.3258
# Accuracy of the model on the 38311 samples: 86.43731565346768 %
# Accuracy of the model on the 12771 samples: 86.82170542635659 %
# Accuracy of the model on the 12771 samples: 86.28924907994676 %
# Epoch [12/1000], Step [300/300], Loss: 0.2013
# Accuracy of the model on the 38311 samples: 86.28592310302524 %
# Accuracy of the model on the 12771 samples: 86.28924907994676 %
# Accuracy of the model on the 12771 samples: 86.00736042596508 %
# Epoch [13/1000], Step [100/300], Loss: 0.2623
# Accuracy of the model on the 38311 samples: 86.09276709039179 %
# Accuracy of the model on the 12771 samples: 86.35972124344218 %
# Accuracy of the model on the 12771 samples: 86.0778325894605 %
# Epoch [13/1000], Step [200/300], Loss: 0.3320
# Accuracy of the model on the 38311 samples: 86.12931011980893 %
# Accuracy of the model on the 12771 samples: 86.36755148383055 %
# Accuracy of the model on the 12771 samples: 86.08566282984887 %
# Epoch [13/1000], Step [300/300], Loss: 0.1984
# Accuracy of the model on the 38311 samples: 86.45297695178931 %
# Accuracy of the model on the 12771 samples: 86.32840028188865 %
# Accuracy of the model on the 12771 samples: 86.11698379140239 %
# Epoch [14/1000], Step [100/300], Loss: 0.2522
# Accuracy of the model on the 38311 samples: 86.45036673540237 %
# Accuracy of the model on the 12771 samples: 86.7355727820844 %
# Accuracy of the model on the 12771 samples: 86.17962571450944 %
# Epoch [14/1000], Step [200/300], Loss: 0.3430
# Accuracy of the model on the 38311 samples: 85.14525854193313 %
# Accuracy of the model on the 12771 samples: 85.73330201237178 %
# Accuracy of the model on the 12771 samples: 85.34962023334117 %
# Epoch [14/1000], Step [300/300], Loss: 0.2213
# Accuracy of the model on the 38311 samples: 86.10320795593955 %
# Accuracy of the model on the 12771 samples: 86.10915355101402 %
# Accuracy of the model on the 12771 samples: 85.92122778169289 %
# Epoch [15/1000], Step [100/300], Loss: 0.2676
# Accuracy of the model on the 38311 samples: 85.95181540549711 %
# Accuracy of the model on the 12771 samples: 86.5398167723749 %
# Accuracy of the model on the 12771 samples: 85.81943465664396 %
# Epoch [15/1000], Step [200/300], Loss: 0.3341
# Accuracy of the model on the 38311 samples: 86.47124846649787 %
# Accuracy of the model on the 12771 samples: 86.71991230130764 %
# Accuracy of the model on the 12771 samples: 86.5398167723749 %
# Epoch [15/1000], Step [300/300], Loss: 0.2186
# Accuracy of the model on the 38311 samples: 86.06927514290935 %
# Accuracy of the model on the 12771 samples: 86.05434186829535 %
# Accuracy of the model on the 12771 samples: 85.31829927178764 %
# Epoch [16/1000], Step [100/300], Loss: 0.2536
# Accuracy of the model on the 38311 samples: 86.40860327321136 %
# Accuracy of the model on the 12771 samples: 86.63377965703548 %
# Accuracy of the model on the 12771 samples: 86.24226763761648 %
# Epoch [16/1000], Step [200/300], Loss: 0.3275
# Accuracy of the model on the 38311 samples: 86.63830231526194 %
# Accuracy of the model on the 12771 samples: 86.67293085897737 %
# Accuracy of the model on the 12771 samples: 86.63377965703548 %
# Epoch [16/1000], Step [300/300], Loss: 0.2334
# Accuracy of the model on the 38311 samples: 86.77403356738273 %
# Accuracy of the model on the 12771 samples: 86.59462845509357 %
# Accuracy of the model on the 12771 samples: 86.24226763761648 %
# Epoch [17/1000], Step [100/300], Loss: 0.2567
# Accuracy of the model on the 38311 samples: 86.47907911565869 %
# Accuracy of the model on the 12771 samples: 86.76689374363794 %
# Accuracy of the model on the 12771 samples: 86.28141883955837 %
# Epoch [17/1000], Step [200/300], Loss: 0.3264
# Accuracy of the model on the 38311 samples: 86.48951998120644 %
# Accuracy of the model on the 12771 samples: 86.55547725315166 %
# Accuracy of the model on the 12771 samples: 86.30490956072352 %
# Epoch [17/1000], Step [300/300], Loss: 0.2140
# Accuracy of the model on the 38311 samples: 86.69311685938764 %
# Accuracy of the model on the 12771 samples: 86.84519614752173 %
# Accuracy of the model on the 12771 samples: 86.27358859917 %
# Epoch [18/1000], Step [100/300], Loss: 0.2503
# Accuracy of the model on the 12771 samples: 86.93915903218229 %
# Epoch [22/1000], Step [300/300], Loss: 0.1957
# Accuracy of the model on the 38311 samples: 86.86800135731252 %
# Accuracy of the model on the 12771 samples: 86.80604494557983 %
# Accuracy of the model on the 12771 samples: 86.62594941664709 %
# Epoch [23/1000], Step [100/300], Loss: 0.2539
# Accuracy of the model on the 38311 samples: 86.5338936597844 %
# Accuracy of the model on the 12771 samples: 86.98614047451257 %
# Accuracy of the model on the 12771 samples: 86.38321196460731 %
# Epoch [23/1000], Step [200/300], Loss: 0.3158
# Accuracy of the model on the 38311 samples: 87.07159823549372 %
# Accuracy of the model on the 12771 samples: 86.96264975334742 %
# Accuracy of the model on the 12771 samples: 86.8530263879101 %
# Epoch [23/1000], Step [300/300], Loss: 0.1991
# Accuracy of the model on the 38311 samples: 86.92542611782517 %
# Accuracy of the model on the 12771 samples: 87.06444287839636 %
# Accuracy of the model on the 12771 samples: 86.75123326286116 %
# Epoch [24/1000], Step [100/300], Loss: 0.2396
# Accuracy of the model on the 38311 samples: 86.8601707081517 %
# Accuracy of the model on the 12771 samples: 87.02529167645447 %
# Accuracy of the model on the 12771 samples: 86.82953566674497 %
# Epoch [24/1000], Step [200/300], Loss: 0.3241
# Accuracy of the model on the 38311 samples: 87.11597191407168 %
# Accuracy of the model on the 12771 samples: 86.79821470519146 %
# Accuracy of the model on the 12771 samples: 86.9313287917939 %
# Epoch [24/1000], Step [300/300], Loss: 0.1678
# Accuracy of the model on the 38311 samples: 87.05332672078515 %
# Accuracy of the model on the 12771 samples: 86.98614047451257 %
# Accuracy of the model on the 12771 samples: 86.68859133975413 %
# Epoch [25/1000], Step [100/300], Loss: 0.2325
# Accuracy of the model on the 38311 samples: 87.23082143509697 %
# Accuracy of the model on the 12771 samples: 87.25236864771749 %
# Accuracy of the model on the 12771 samples: 86.82170542635659 %
# Epoch [25/1000], Step [200/300], Loss: 0.3178
# Accuracy of the model on the 38311 samples: 87.0768186682676 %
# Accuracy of the model on the 12771 samples: 87.11142432072664 %
# Accuracy of the model on the 12771 samples: 87.0487823976196 %
# Epoch [25/1000], Step [300/300], Loss: 0.1550
# Accuracy of the model on the 38311 samples: 87.43963874605205 %
# Accuracy of the model on the 12771 samples: 87.36982225354318 %
# Accuracy of the model on the 12771 samples: 87.10359408033827 %
# Epoch [26/1000], Step [100/300], Loss: 0.2369
# Accuracy of the model on the 38311 samples: 86.9071546031166 %
# Accuracy of the model on the 12771 samples: 86.89217758985201 %
# Accuracy of the model on the 12771 samples: 86.59462845509357 %
# Epoch [26/1000], Step [200/300], Loss: 0.3182
# Accuracy of the model on the 38311 samples: 86.57304690558847 %
# Accuracy of the model on the 12771 samples: 86.69642158014251 %
# Accuracy of the model on the 12771 samples: 86.25009787800485 %
# Epoch [26/1000], Step [300/300], Loss: 0.1849
# Accuracy of the model on the 38311 samples: 87.33000965780063 %
# Accuracy of the model on the 12771 samples: 87.27585936888262 %
# Accuracy of the model on the 12771 samples: 86.64160989742385 %
# Epoch [27/1000], Step [100/300], Loss: 0.2418
# Accuracy of the model on the 38311 samples: 87.03766542246352 %
# Accuracy of the model on the 12771 samples: 87.18972672461045 %
# Accuracy of the model on the 12771 samples: 86.84519614752173 %
# Epoch [27/1000], Step [200/300], Loss: 0.3097
# Accuracy of the model on the 38311 samples: 87.41092636579573 %
# Accuracy of the model on the 12771 samples: 87.28368960927101 %
# Accuracy of the model on the 12771 samples: 87.08010335917312 %
# Epoch [27/1000], Step [300/300], Loss: 0.1713
# Accuracy of the model on the 38311 samples: 87.50750437211245 %
# Accuracy of the model on the 12771 samples: 87.40897345548508 %
# Accuracy of the model on the 12771 samples: 86.96264975334742 %
# Epoch [28/1000], Step [100/300], Loss: 0.2474
# Accuracy of the model on the 38311 samples: 86.93064655059905 %
# Accuracy of the model on the 12771 samples: 86.9783102341242 %
# Accuracy of the model on the 12771 samples: 86.57896797431681 %
# Epoch [28/1000], Step [200/300], Loss: 0.3184
# Accuracy of the model on the 38311 samples: 87.23082143509697 %
# Accuracy of the model on the 12771 samples: 87.1270848015034 %
# Accuracy of the model on the 12771 samples: 86.9313287917939 %
# Epoch [28/1000], Step [300/300], Loss: 0.1564
# Accuracy of the model on the 38311 samples: 87.2595338153533 %
# Accuracy of the model on the 12771 samples: 87.26802912849425 %
# Accuracy of the model on the 12771 samples: 86.62594941664709 %
# Epoch [29/1000], Step [100/300], Loss: 0.2516
# Accuracy of the model on the 38311 samples: 87.20471927122759 %
# Accuracy of the model on the 12771 samples: 86.9783102341242 %
# Accuracy of the model on the 12771 samples: 86.82170542635659 %
# Epoch [29/1000], Step [200/300], Loss: 0.2914
# Accuracy of the model on the 38311 samples: 87.53099631959489 %
# Accuracy of the model on the 12771 samples: 87.23670816694073 %
# Accuracy of the model on the 12771 samples: 87.03312191684284 %
# Epoch [29/1000], Step [300/300], Loss: 0.1654
# Accuracy of the model on the 38311 samples: 87.54404740152958 %
# Accuracy of the model on the 12771 samples: 87.54208754208754 %
# Accuracy of the model on the 12771 samples: 86.9783102341242 %
# Epoch [30/1000], Step [100/300], Loss: 0.2666
# Accuracy of the model on the 38311 samples: 86.98546109472476 %
# Accuracy of the model on the 12771 samples: 86.93915903218229 %
# Accuracy of the model on the 12771 samples: 86.64944013781223 %
# Epoch [30/1000], Step [200/300], Loss: 0.3268
# Accuracy of the model on the 38311 samples: 87.24126230064472 %
# Accuracy of the model on the 12771 samples: 86.84519614752173 %
# Accuracy of the model on the 12771 samples: 87.11925456111503 %
# Epoch [30/1000], Step [300/300], Loss: 0.1609
# Accuracy of the model on the 38311 samples: 87.42658766411735 %
# Accuracy of the model on the 12771 samples: 87.18189648422207 %
# Accuracy of the model on the 12771 samples: 86.7825542244147 %
# Epoch [31/1000], Step [100/300], Loss: 0.2454
# Accuracy of the model on the 38311 samples: 86.93064655059905 %
# Accuracy of the model on the 12771 samples: 87.0487823976196 %
# Accuracy of the model on the 12771 samples: 86.86868686868686 %
# Epoch [31/1000], Step [200/300], Loss: 0.3148
# Accuracy of the model on the 38311 samples: 87.06898801910678 %
# Accuracy of the model on the 12771 samples: 87.00963119567771 %
# Accuracy of the model on the 12771 samples: 87.00963119567771 %
# Epoch [31/1000], Step [300/300], Loss: 0.1924
# Accuracy of the model on the 38311 samples: 86.82884811150845 %
# Accuracy of the model on the 12771 samples: 87.10359408033827 %
# Accuracy of the model on the 12771 samples: 86.40670268577246 %
# Epoch [32/1000], Step [100/300], Loss: 0.2383
# Accuracy of the model on the 38311 samples: 87.17078645819738 %
# Accuracy of the model on the 12771 samples: 87.28368960927101 %
# Accuracy of the model on the 12771 samples: 86.91566831101714 %
# Epoch [32/1000], Step [200/300], Loss: 0.3227
# Accuracy of the model on the 38311 samples: 87.41092636579573 %
# Accuracy of the model on the 12771 samples: 87.15840576305692 %
# Accuracy of the model on the 12771 samples: 86.76689374363794 %
# Epoch [32/1000], Step [300/300], Loss: 0.2711
# Accuracy of the model on the 38311 samples: 86.29636396857299 %
# Accuracy of the model on the 12771 samples: 86.3518910030538 %
# Accuracy of the model on the 12771 samples: 86.01519066635346 %
# Epoch [33/1000], Step [100/300], Loss: 0.2339
# Accuracy of the model on the 38311 samples: 87.44485917882592 %
# Accuracy of the model on the 12771 samples: 87.30718033043614 %
# Accuracy of the model on the 12771 samples: 86.8530263879101 %
# Epoch [33/1000], Step [200/300], Loss: 0.3018
# Accuracy of the model on the 38311 samples: 87.38482420192634 %
# Accuracy of the model on the 12771 samples: 86.97047999373581 %
# Accuracy of the model on the 12771 samples: 87.1662360034453 %
# Epoch [33/1000], Step [300/300], Loss: 0.1677
# Accuracy of the model on the 38311 samples: 87.5988619456553 %
# Accuracy of the model on the 12771 samples: 87.30718033043614 %
# Accuracy of the model on the 12771 samples: 87.01746143606609 %
# Epoch [34/1000], Step [100/300], Loss: 0.2291
# Accuracy of the model on the 38311 samples: 87.67977865365039 %
# Accuracy of the model on the 12771 samples: 87.58123874402945 %
# Accuracy of the model on the 12771 samples: 86.96264975334742 %
# Epoch [34/1000], Step [200/300], Loss: 0.3011
# Accuracy of the model on the 38311 samples: 87.57798021455979 %
# Accuracy of the model on the 12771 samples: 87.19755696499882 %
# Accuracy of the model on the 12771 samples: 87.21321744577558 %
# Epoch [34/1000], Step [300/300], Loss: 0.1597
# Accuracy of the model on the 38311 samples: 87.71110125029365 %
# Accuracy of the model on the 12771 samples: 87.40114321509671 %
# Accuracy of the model on the 12771 samples: 87.11925456111503 %
# Epoch [35/1000], Step [100/300], Loss: 0.2276
# Accuracy of the model on the 38311 samples: 87.33261987418757 %
# Accuracy of the model on the 12771 samples: 87.7535040325738 %
# Accuracy of the model on the 12771 samples: 86.82953566674497 %
# Epoch [35/1000], Step [200/300], Loss: 0.3001
# Accuracy of the model on the 38311 samples: 87.52055545404714 %
# Accuracy of the model on the 12771 samples: 87.04095215723123 %
# Accuracy of the model on the 12771 samples: 86.96264975334742 %
# Epoch [35/1000], Step [300/300], Loss: 0.1745
# Accuracy of the model on the 38311 samples: 87.6197436767508 %
# Accuracy of the model on the 12771 samples: 87.3619920131548 %
# Accuracy of the model on the 12771 samples: 87.11925456111503 %
# Epoch [36/1000], Step [100/300], Loss: 0.2212
# Accuracy of the model on the 38311 samples: 87.85205293518833 %
# Accuracy of the model on the 12771 samples: 87.58906898441782 %
# Accuracy of the model on the 12771 samples: 87.08793359956151 %
# Epoch [36/1000], Step [200/300], Loss: 0.3294
# Accuracy of the model on the 38311 samples: 86.74271097073948 %
# Accuracy of the model on the 12771 samples: 87.01746143606609 %
# Accuracy of the model on the 12771 samples: 86.665100618589 %
# Epoch [36/1000], Step [300/300], Loss: 0.1639
# Accuracy of the model on the 38311 samples: 87.12641277961943 %
# Accuracy of the model on the 12771 samples: 87.31501057082453 %
# Accuracy of the model on the 12771 samples: 86.89217758985201 %
# Epoch [37/1000], Step [100/300], Loss: 0.2281
# Accuracy of the model on the 38311 samples: 87.33523009057451 %
# Accuracy of the model on the 12771 samples: 87.26019888810586 %
# Accuracy of the model on the 12771 samples: 87.00180095528933 %
# Epoch [37/1000], Step [200/300], Loss: 0.3029
# Accuracy of the model on the 38311 samples: 87.75025449609772 %
# Accuracy of the model on the 12771 samples: 87.42463393626184 %
# Accuracy of the model on the 12771 samples: 87.20538720538721 %
# Epoch [37/1000], Step [300/300], Loss: 0.1507
# Accuracy of the model on the 38311 samples: 87.68238887003733 %
# Accuracy of the model on the 12771 samples: 87.52642706131078 %
# Accuracy of the model on the 12771 samples: 87.06444287839636 %
# Epoch [38/1000], Step [100/300], Loss: 0.2502
# Accuracy of the model on the 38311 samples: 87.59364151288142 %
# Accuracy of the model on the 12771 samples: 87.65954114791325 %
# Accuracy of the model on the 12771 samples: 87.11925456111503 %
# Epoch [38/1000], Step [200/300], Loss: 0.3052
# Accuracy of the model on the 38311 samples: 87.72937276500222 %
# Accuracy of the model on the 12771 samples: 87.5185968209224 %
# Accuracy of the model on the 12771 samples: 87.26019888810586 %
# Epoch [38/1000], Step [300/300], Loss: 0.1380
# Accuracy of the model on the 38311 samples: 87.71632168306752 %
# Accuracy of the model on the 12771 samples: 87.5577480228643 %
# Accuracy of the model on the 12771 samples: 87.28368960927101 %
# Epoch [39/1000], Step [100/300], Loss: 0.2211
# Accuracy of the model on the 38311 samples: 87.95385137427893 %
# Accuracy of the model on the 12771 samples: 87.74567379218541 %
# Accuracy of the model on the 12771 samples: 87.26802912849425 %
# Epoch [39/1000], Step [200/300], Loss: 0.3001
# Accuracy of the model on the 38311 samples: 87.823340554932 %
# Accuracy of the model on the 12771 samples: 87.25236864771749 %
# Accuracy of the model on the 12771 samples: 87.15840576305692 %
# Epoch [39/1000], Step [300/300], Loss: 0.1693
# Accuracy of the model on the 38311 samples: 87.51272480488632 %
# Accuracy of the model on the 12771 samples: 87.13491504189179 %
# Accuracy of the model on the 12771 samples: 86.74340302247279 %
# Epoch [40/1000], Step [100/300], Loss: 0.2413
# Accuracy of the model on the 38311 samples: 87.97473310537444 %
# Accuracy of the model on the 12771 samples: 87.6360504267481 %
# Accuracy of the model on the 12771 samples: 87.03312191684284 %
# Epoch [40/1000], Step [200/300], Loss: 0.2914
# Accuracy of the model on the 38311 samples: 87.95907180705281 %
# Accuracy of the model on the 12771 samples: 87.65171090752486 %
# Accuracy of the model on the 12771 samples: 87.43246417665023 %
# Epoch [40/1000], Step [300/300], Loss: 0.1398
# Accuracy of the model on the 38311 samples: 87.95907180705281 %
# Accuracy of the model on the 12771 samples: 87.49510609975727 %
# Accuracy of the model on the 12771 samples: 86.8530263879101 %
# Epoch [41/1000], Step [100/300], Loss: 0.2493
# Accuracy of the model on the 38311 samples: 87.4631306935345 %
# Accuracy of the model on the 12771 samples: 87.47161537859212 %
# Accuracy of the model on the 12771 samples: 86.75123326286116 %
# Epoch [41/1000], Step [200/300], Loss: 0.2829
# Accuracy of the model on the 38311 samples: 88.07914176085197 %
# Accuracy of the model on the 12771 samples: 87.62822018635973 %
# Accuracy of the model on the 12771 samples: 87.26019888810586 %
# Epoch [41/1000], Step [300/300], Loss: 0.1547
# Accuracy of the model on the 38311 samples: 87.87815509905771 %
# Accuracy of the model on the 12771 samples: 87.50293634014564 %
# Accuracy of the model on the 12771 samples: 87.1662360034453 %
# Epoch [42/1000], Step [100/300], Loss: 0.2280
# Accuracy of the model on the 38311 samples: 87.88859596460547 %
# Accuracy of the model on the 12771 samples: 87.87878787878788 %
# Accuracy of the model on the 12771 samples: 87.31501057082453 %
# Epoch [42/1000], Step [200/300], Loss: 0.2853
# Accuracy of the model on the 38311 samples: 87.8363916368667 %
# Accuracy of the model on the 12771 samples: 87.26802912849425 %
# Accuracy of the model on the 12771 samples: 87.1270848015034 %
# Epoch [42/1000], Step [300/300], Loss: 0.1588
# Accuracy of the model on the 38311 samples: 87.45268982798675 %
# Accuracy of the model on the 12771 samples: 87.26802912849425 %
# Accuracy of the model on the 12771 samples: 87.03312191684284 %
# Epoch [43/1000], Step [100/300], Loss: 0.2196
# Accuracy of the model on the 38311 samples: 87.69805016835896 %
# Accuracy of the model on the 12771 samples: 87.74567379218541 %
# Accuracy of the model on the 12771 samples: 86.7825542244147 %
# Epoch [43/1000], Step [200/300], Loss: 0.2866
# Accuracy of the model on the 38311 samples: 87.97995353814831 %
# Accuracy of the model on the 12771 samples: 87.64388066713649 %
# Accuracy of the model on the 12771 samples: 87.20538720538721 %
# Epoch [43/1000], Step [300/300], Loss: 0.1530
# Accuracy of the model on the 38311 samples: 87.30912792670513 %
# Accuracy of the model on the 12771 samples: 87.25236864771749 %
# Accuracy of the model on the 12771 samples: 86.90000783024038 %
# Epoch [44/1000], Step [100/300], Loss: 0.2281
# Accuracy of the model on the 38311 samples: 87.88076531544465 %
# Accuracy of the model on the 12771 samples: 87.66737138830162 %
# Accuracy of the model on the 12771 samples: 87.14274528228016 %
# Epoch [44/1000], Step [200/300], Loss: 0.2737
# Accuracy of the model on the 38311 samples: 88.0399885150479 %
# Accuracy of the model on the 12771 samples: 87.61255970558297 %
# Accuracy of the model on the 12771 samples: 87.46378513820375 %
# Epoch [44/1000], Step [300/300], Loss: 0.1527
# Accuracy of the model on the 38311 samples: 87.67194800448958 %
# Accuracy of the model on the 12771 samples: 87.41680369587347 %
# Accuracy of the model on the 12771 samples: 86.98614047451257 %
# Epoch [45/1000], Step [100/300], Loss: 0.2270
# Accuracy of the model on the 38311 samples: 88.17049933439482 %
# Accuracy of the model on the 12771 samples: 87.74567379218541 %
# Accuracy of the model on the 12771 samples: 87.33850129198966 %
# Epoch [45/1000], Step [200/300], Loss: 0.2814
# Accuracy of the model on the 38311 samples: 88.2305343112944 %
# Accuracy of the model on the 12771 samples: 87.93359956150654 %
# Accuracy of the model on the 12771 samples: 87.4402944170386 %
# Epoch [45/1000], Step [300/300], Loss: 0.1448
# Accuracy of the model on the 38311 samples: 87.71893189945446 %
# Accuracy of the model on the 12771 samples: 87.17406624383369 %
# Accuracy of the model on the 12771 samples: 86.91566831101714 %
# Epoch [46/1000], Step [100/300], Loss: 0.2117
# Accuracy of the model on the 38311 samples: 88.24880582600298 %
# Accuracy of the model on the 12771 samples: 87.9492600422833 %
# Accuracy of the model on the 12771 samples: 87.29935009004777 %
# Epoch [46/1000], Step [200/300], Loss: 0.2831
# Accuracy of the model on the 38311 samples: 88.38453707812377 %
# Accuracy of the model on the 12771 samples: 87.9492600422833 %
# Accuracy of the model on the 12771 samples: 87.47161537859212 %
# Epoch [46/1000], Step [300/300], Loss: 0.1364
# Accuracy of the model on the 38311 samples: 87.22560100232309 %
# Accuracy of the model on the 12771 samples: 87.00963119567771 %
# Accuracy of the model on the 12771 samples: 86.64160989742385 %
# Epoch [47/1000], Step [100/300], Loss: 0.2209
# Accuracy of the model on the 38311 samples: 88.07653154446504 %
# Accuracy of the model on the 12771 samples: 87.9101088403414 %
# Accuracy of the model on the 12771 samples: 87.60472946519458 %
# Epoch [47/1000], Step [200/300], Loss: 0.2726
# Accuracy of the model on the 38311 samples: 88.04520894782178 %
# Accuracy of the model on the 12771 samples: 87.53425730169916 %
# Accuracy of the model on the 12771 samples: 86.90783807062877 %
# Epoch [47/1000], Step [300/300], Loss: 0.1745
# Accuracy of the model on the 38311 samples: 87.32478922502675 %
# Accuracy of the model on the 12771 samples: 87.06444287839636 %
# Accuracy of the model on the 12771 samples: 86.79038446480307 %
# Epoch [48/1000], Step [100/300], Loss: 0.2225
# Accuracy of the model on the 38311 samples: 88.07131111169116 %
# Accuracy of the model on the 12771 samples: 87.6360504267481 %
# Accuracy of the model on the 12771 samples: 87.06444287839636 %
# Epoch [48/1000], Step [200/300], Loss: 0.2683
# Accuracy of the model on the 38311 samples: 88.26185690793767 %
# Accuracy of the model on the 12771 samples: 87.7535040325738 %
# Accuracy of the model on the 12771 samples: 87.28368960927101 %
# Epoch [48/1000], Step [300/300], Loss: 0.1438
# Accuracy of the model on the 38311 samples: 87.25170316619247 %
# Accuracy of the model on the 12771 samples: 86.69642158014251 %
# Accuracy of the model on the 12771 samples: 86.50849581082139 %
# Epoch [49/1000], Step [100/300], Loss: 0.2305
# Accuracy of the model on the 38311 samples: 88.2305343112944 %
# Accuracy of the model on the 12771 samples: 88.0275624461671 %
# Accuracy of the model on the 12771 samples: 87.38548273431995 %
# Epoch [49/1000], Step [200/300], Loss: 0.2762
# Accuracy of the model on the 38311 samples: 88.2435853932291 %
# Accuracy of the model on the 12771 samples: 87.74567379218541 %
# Accuracy of the model on the 12771 samples: 87.31501057082453 %
# Epoch [49/1000], Step [300/300], Loss: 0.1379
# Accuracy of the model on the 38311 samples: 87.47357155908225 %
# Accuracy of the model on the 12771 samples: 87.18189648422207 %
# Accuracy of the model on the 12771 samples: 86.86868686868686 %
# Epoch [50/1000], Step [100/300], Loss: 0.2311
# Accuracy of the model on the 38311 samples: 88.0060557020177 %
# Accuracy of the model on the 12771 samples: 87.77699475373893 %
# Accuracy of the model on the 12771 samples: 87.19755696499882 %
# Epoch [50/1000], Step [200/300], Loss: 0.2898
# Accuracy of the model on the 38311 samples: 88.05042938059565 %
# Accuracy of the model on the 12771 samples: 87.58906898441782 %
# Accuracy of the model on the 12771 samples: 87.22887792655234 %
# Epoch [50/1000], Step [300/300], Loss: 0.1440
# Accuracy of the model on the 38311 samples: 87.70849103390671 %
# Accuracy of the model on the 12771 samples: 87.17406624383369 %
# Accuracy of the model on the 12771 samples: 86.75906350324955 %
# Epoch [51/1000], Step [100/300], Loss: 0.2177
# Accuracy of the model on the 38311 samples: 88.30362037012868 %
# Accuracy of the model on the 12771 samples: 87.87878787878788 %
# Accuracy of the model on the 12771 samples: 87.21321744577558 %
# Epoch [51/1000], Step [200/300], Loss: 0.2937
# Accuracy of the model on the 38311 samples: 88.21226279658583 %
# Accuracy of the model on the 12771 samples: 87.59689922480621 %
# Accuracy of the model on the 12771 samples: 87.33850129198966 %
# Epoch [51/1000], Step [300/300], Loss: 0.1278
# Accuracy of the model on the 38311 samples: 87.8024588238365 %
# Accuracy of the model on the 12771 samples: 87.44812465742699 %
# Accuracy of the model on the 12771 samples: 86.90000783024038 %
# Epoch [52/1000], Step [100/300], Loss: 0.2062
# Accuracy of the model on the 38311 samples: 88.28534885542011 %
# Accuracy of the model on the 12771 samples: 88.17633701354632 %
# Accuracy of the model on the 12771 samples: 87.65954114791325 %
# Epoch [52/1000], Step [200/300], Loss: 0.2819
# Accuracy of the model on the 38311 samples: 88.2775182062593 %
# Accuracy of the model on the 12771 samples: 87.73784355179704 %
# Accuracy of the model on the 12771 samples: 87.29935009004777 %
# Epoch [52/1000], Step [300/300], Loss: 0.1324
# Accuracy of the model on the 38311 samples: 87.73720341416303 %
# Accuracy of the model on the 12771 samples: 87.26019888810586 %
# Accuracy of the model on the 12771 samples: 87.02529167645447 %
# Epoch [53/1000], Step [100/300], Loss: 0.2134
# Accuracy of the model on the 38311 samples: 88.37148599618908 %
# Accuracy of the model on the 12771 samples: 87.9101088403414 %
# Accuracy of the model on the 12771 samples: 87.42463393626184 %
# Epoch [53/1000], Step [200/300], Loss: 0.2857
# Accuracy of the model on the 38311 samples: 87.98256375453525 %
# Accuracy of the model on the 12771 samples: 87.37765249393156 %
# Accuracy of the model on the 12771 samples: 86.74340302247279 %
# Epoch [53/1000], Step [300/300], Loss: 0.1281
# Accuracy of the model on the 38311 samples: 87.69805016835896 %
# Accuracy of the model on the 12771 samples: 87.40114321509671 %
# Accuracy of the model on the 12771 samples: 87.1662360034453 %
# Epoch [54/1000], Step [100/300], Loss: 0.2207
# Accuracy of the model on the 38311 samples: 88.19138106549033 %
# Accuracy of the model on the 12771 samples: 87.5577480228643 %
# Accuracy of the model on the 12771 samples: 87.14274528228016 %
# Epoch [54/1000], Step [200/300], Loss: 0.2654
# Accuracy of the model on the 38311 samples: 88.41585967476703 %
# Accuracy of the model on the 12771 samples: 87.87878787878788 %
# Accuracy of the model on the 12771 samples: 87.36982225354318 %
# Epoch [54/1000], Step [300/300], Loss: 0.1335
# Accuracy of the model on the 38311 samples: 87.99561483646994 %
# Accuracy of the model on the 12771 samples: 87.18189648422207 %
# Accuracy of the model on the 12771 samples: 87.20538720538721 %
# Epoch [55/1000], Step [100/300], Loss: 0.2061
# Accuracy of the model on the 38311 samples: 88.43413118947561 %
# Accuracy of the model on the 12771 samples: 87.9492600422833 %
# Accuracy of the model on the 12771 samples: 87.30718033043614 %
# Epoch [55/1000], Step [200/300], Loss: 0.2838
# Accuracy of the model on the 38311 samples: 88.67949152984782 %
# Accuracy of the model on the 12771 samples: 87.90227859995302 %
# Accuracy of the model on the 12771 samples: 87.40897345548508 %
# Epoch [55/1000], Step [300/300], Loss: 0.1290
# Accuracy of the model on the 38311 samples: 87.8363916368667 %
# Accuracy of the model on the 12771 samples: 87.30718033043614 %
# Accuracy of the model on the 12771 samples: 87.00963119567771 %
# Epoch [56/1000], Step [100/300], Loss: 0.2276
# Accuracy of the model on the 38311 samples: 88.31145101928949 %
# Accuracy of the model on the 12771 samples: 87.91793908072978 %
# Accuracy of the model on the 12771 samples: 87.4794456189805 %
# Epoch [56/1000], Step [200/300], Loss: 0.2815
# Accuracy of the model on the 38311 samples: 88.47589465166662 %
# Accuracy of the model on the 12771 samples: 87.87878787878788 %
# Accuracy of the model on the 12771 samples: 87.4402944170386 %
# Epoch [56/1000], Step [300/300], Loss: 0.1300
# Accuracy of the model on the 38311 samples: 88.05303959698259 %
# Accuracy of the model on the 12771 samples: 87.45595489781536 %
# Accuracy of the model on the 12771 samples: 87.08010335917312 %
# Epoch [57/1000], Step [100/300], Loss: 0.2089
# Accuracy of the model on the 38311 samples: 88.25663647516379 %
# Accuracy of the model on the 12771 samples: 87.91793908072978 %
# Accuracy of the model on the 12771 samples: 87.4402944170386 %
# Epoch [57/1000], Step [200/300], Loss: 0.2852
# Accuracy of the model on the 38311 samples: 88.4263005403148 %
# Accuracy of the model on the 12771 samples: 87.62822018635973 %
# Accuracy of the model on the 12771 samples: 87.60472946519458 %
# Epoch [57/1000], Step [300/300], Loss: 0.1345
# Accuracy of the model on the 38311 samples: 88.2983999373548 %
# Accuracy of the model on the 12771 samples: 87.89444835956463 %
# Accuracy of the model on the 12771 samples: 87.22887792655234 %
# Epoch [58/1000], Step [100/300], Loss: 0.2022
# Accuracy of the model on the 38311 samples: 88.24097517684216 %
# Accuracy of the model on the 12771 samples: 87.48727585936888 %
# Accuracy of the model on the 12771 samples: 87.4402944170386 %
# Epoch [58/1000], Step [200/300], Loss: 0.2704
# Accuracy of the model on the 38311 samples: 88.67688131346088 %
# Accuracy of the model on the 12771 samples: 87.99624148461358 %
# Accuracy of the model on the 12771 samples: 87.53425730169916 %
# Epoch [58/1000], Step [300/300], Loss: 0.1057
# Accuracy of the model on the 38311 samples: 88.29578972096787 %
# Accuracy of the model on the 12771 samples: 87.58123874402945 %
# Accuracy of the model on the 12771 samples: 87.21321744577558 %
# Epoch [59/1000], Step [100/300], Loss: 0.2294
# Accuracy of the model on the 38311 samples: 88.63511785126987 %
# Accuracy of the model on the 12771 samples: 88.29379061937202 %
# Accuracy of the model on the 12771 samples: 87.80831571529247 %
# Epoch [59/1000], Step [200/300], Loss: 0.2680
# Accuracy of the model on the 38311 samples: 88.79434105087311 %
# Accuracy of the model on the 12771 samples: 87.76916451335056 %
# Accuracy of the model on the 12771 samples: 87.45595489781536 %
# Epoch [59/1000], Step [300/300], Loss: 0.1251
# Accuracy of the model on the 38311 samples: 88.30884080290257 %
# Accuracy of the model on the 12771 samples: 87.54208754208754 %
# Accuracy of the model on the 12771 samples: 87.06444287839636 %
# Epoch [60/1000], Step [100/300], Loss: 0.2080
# Accuracy of the model on the 38311 samples: 88.70298347733026 %
# Accuracy of the model on the 12771 samples: 88.2233184558766 %
# Accuracy of the model on the 12771 samples: 87.62038994597134 %
# Epoch [60/1000], Step [200/300], Loss: 0.2786
# Accuracy of the model on the 38311 samples: 88.50982746469683 %
# Accuracy of the model on the 12771 samples: 87.78482499412732 %
# Accuracy of the model on the 12771 samples: 87.58906898441782 %
# Epoch [60/1000], Step [300/300], Loss: 0.1176
# Accuracy of the model on the 38311 samples: 88.53331941217927 %
# Accuracy of the model on the 12771 samples: 87.64388066713649 %
# Accuracy of the model on the 12771 samples: 86.98614047451257 %
# Epoch [61/1000], Step [100/300], Loss: 0.2111
# Accuracy of the model on the 38311 samples: 88.46023335334499 %
# Accuracy of the model on the 12771 samples: 88.00407172500196 %
# Accuracy of the model on the 12771 samples: 87.68303186907838 %
# Epoch [61/1000], Step [200/300], Loss: 0.2707
# Accuracy of the model on the 38311 samples: 88.58030330714416 %
# Accuracy of the model on the 12771 samples: 87.93359956150654 %
# Accuracy of the model on the 12771 samples: 87.42463393626184 %
# Epoch [61/1000], Step [300/300], Loss: 0.1287
# Accuracy of the model on the 38311 samples: 88.30101015374174 %
# Accuracy of the model on the 12771 samples: 87.76916451335056 %
# Accuracy of the model on the 12771 samples: 87.21321744577558 %
# Epoch [62/1000], Step [100/300], Loss: 0.2183
# Accuracy of the model on the 38311 samples: 88.39758816005848 %
# Accuracy of the model on the 12771 samples: 88.0275624461671 %
# Accuracy of the model on the 12771 samples: 87.05661263800799 %
# Epoch [62/1000], Step [200/300], Loss: 0.2954
# Accuracy of the model on the 38311 samples: 88.58030330714416 %
# Accuracy of the model on the 12771 samples: 87.69086210946676 %
# Accuracy of the model on the 12771 samples: 87.20538720538721 %
# Epoch [62/1000], Step [300/300], Loss: 0.1359
# Accuracy of the model on the 38311 samples: 88.13656652136463 %
# Accuracy of the model on the 12771 samples: 87.07227311878475 %
# Accuracy of the model on the 12771 samples: 86.75906350324955 %
# Epoch [63/1000], Step [100/300], Loss: 0.2183
# Accuracy of the model on the 38311 samples: 88.31406123567643 %
# Accuracy of the model on the 12771 samples: 87.8709576383995 %
# Accuracy of the model on the 12771 samples: 87.58906898441782 %
# Epoch [63/1000], Step [200/300], Loss: 0.2774
# Accuracy of the model on the 38311 samples: 88.53070919579233 %
# Accuracy of the model on the 12771 samples: 87.43246417665023 %
# Accuracy of the model on the 12771 samples: 87.22887792655234 %
# Epoch [63/1000], Step [300/300], Loss: 0.1008
# Accuracy of the model on the 38311 samples: 88.35060426509358 %
# Accuracy of the model on the 12771 samples: 87.61255970558297 %
# Accuracy of the model on the 12771 samples: 87.14274528228016 %
# Epoch [64/1000], Step [100/300], Loss: 0.2017
# Accuracy of the model on the 38311 samples: 88.86481689332045 %
# Accuracy of the model on the 12771 samples: 88.17633701354632 %
# Accuracy of the model on the 12771 samples: 87.77699475373893 %
# Epoch [64/1000], Step [200/300], Loss: 0.2773
# Accuracy of the model on the 38311 samples: 89.06580355511471 %
# Accuracy of the model on the 12771 samples: 88.00407172500196 %
# Accuracy of the model on the 12771 samples: 87.60472946519458 %
# Epoch [64/1000], Step [300/300], Loss: 0.1100
# Accuracy of the model on the 38311 samples: 88.67166088068701 %
# Accuracy of the model on the 12771 samples: 87.82397619606922 %
# Accuracy of the model on the 12771 samples: 87.27585936888262 %
# Epoch [65/1000], Step [100/300], Loss: 0.2189
# Accuracy of the model on the 38311 samples: 88.93007230299392 %
# Accuracy of the model on the 12771 samples: 88.09020436927413 %
# Accuracy of the model on the 12771 samples: 87.62038994597134 %
# Epoch [65/1000], Step [200/300], Loss: 0.2733
# Accuracy of the model on the 38311 samples: 88.67166088068701 %
# Accuracy of the model on the 12771 samples: 87.80048547490408 %
# Accuracy of the model on the 12771 samples: 87.3228408112129 %
# Epoch [65/1000], Step [300/300], Loss: 0.1237
# Accuracy of the model on the 38311 samples: 88.38192686173684 %
# Accuracy of the model on the 12771 samples: 87.80048547490408 %
# Accuracy of the model on the 12771 samples: 87.11142432072664 %
# Epoch [66/1000], Step [100/300], Loss: 0.2199
# Accuracy of the model on the 38311 samples: 88.7055936937172 %
# Accuracy of the model on the 12771 samples: 88.05105316733224 %
# Accuracy of the model on the 12771 samples: 87.66737138830162 %
# Epoch [66/1000], Step [200/300], Loss: 0.2739
# Accuracy of the model on the 38311 samples: 88.81261256558169 %
# Accuracy of the model on the 12771 samples: 87.8709576383995 %
# Accuracy of the model on the 12771 samples: 87.58906898441782 %
# Epoch [66/1000], Step [300/300], Loss: 0.1529
# Accuracy of the model on the 38311 samples: 87.823340554932 %
# Accuracy of the model on the 12771 samples: 87.30718033043614 %
# Accuracy of the model on the 12771 samples: 87.1662360034453 %
# Epoch [67/1000], Step [100/300], Loss: 0.2171
# Accuracy of the model on the 38311 samples: 88.28273863903317 %
# Accuracy of the model on the 12771 samples: 87.40897345548508 %
# Accuracy of the model on the 12771 samples: 87.2445384073291 %
# Epoch [67/1000], Step [200/300], Loss: 0.2746
# Accuracy of the model on the 38311 samples: 89.00576857821514 %
# Accuracy of the model on the 12771 samples: 88.15284629238117 %
# Accuracy of the model on the 12771 samples: 87.7143528306319 %
# Epoch [67/1000], Step [300/300], Loss: 0.1159
# Accuracy of the model on the 38311 samples: 88.60901568740049 %
# Accuracy of the model on the 12771 samples: 87.62822018635973 %
# Accuracy of the model on the 12771 samples: 87.36982225354318 %
# Epoch [68/1000], Step [100/300], Loss: 0.2047
# Accuracy of the model on the 38311 samples: 88.84132494583801 %
# Accuracy of the model on the 12771 samples: 87.93359956150654 %
# Accuracy of the model on the 12771 samples: 87.66737138830162 %
# Epoch [68/1000], Step [200/300], Loss: 0.2659
# ...
# Epoch [978/1000], Step [300/300], Loss: 0.1711
# Accuracy of the model on the 38311 samples: 85.64642008822531 %
# Accuracy of the model on the 12771 samples: 85.87424633936261 %
# Accuracy of the model on the 12771 samples: 85.39660167567145 %
# Epoch [979/1000], Step [100/300], Loss: 0.2320
# Accuracy of the model on the 38311 samples: 86.41382370598522 %
# Accuracy of the model on the 12771 samples: 86.4693446088795 %
# Accuracy of the model on the 12771 samples: 86.1561349933443 %
# Epoch [979/1000], Step [200/300], Loss: 0.3515
# Accuracy of the model on the 38311 samples: 86.00140951684895 %
# Accuracy of the model on the 12771 samples: 86.14047451256754 %
# Accuracy of the model on the 12771 samples: 86.10915355101402 %
# Epoch [979/1000], Step [300/300], Loss: 0.1768
# Accuracy of the model on the 38311 samples: 85.64380987183837 %
# Accuracy of the model on the 12771 samples: 85.86641609897424 %
# Accuracy of the model on the 12771 samples: 85.49839480072038 %
# Epoch [980/1000], Step [100/300], Loss: 0.2540
# Accuracy of the model on the 38311 samples: 86.15280206729138 %
# Accuracy of the model on the 12771 samples: 86.43802364732598 %
# Accuracy of the model on the 12771 samples: 85.9603789836348 %
# Epoch [980/1000], Step [200/300], Loss: 0.3479
# Accuracy of the model on the 38311 samples: 86.21283704419096 %
# Accuracy of the model on the 12771 samples: 86.25009787800485 %
# Accuracy of the model on the 12771 samples: 86.1952861952862 %
# Epoch [980/1000], Step [300/300], Loss: 0.1915
# Accuracy of the model on the 38311 samples: 85.82652501892407 %
# Accuracy of the model on the 12771 samples: 86.25792811839324 %
# Accuracy of the model on the 12771 samples: 85.6863205700415 %
# Epoch [981/1000], Step [100/300], Loss: 0.2568
# Accuracy of the model on the 38311 samples: 86.3172456996685 %
# Accuracy of the model on the 12771 samples: 86.56330749354005 %
# Accuracy of the model on the 12771 samples: 86.14830475295591 %
# Epoch [981/1000], Step [200/300], Loss: 0.3596
# Accuracy of the model on the 38311 samples: 86.00401973323588 %
# Accuracy of the model on the 12771 samples: 86.11698379140239 %
# Accuracy of the model on the 12771 samples: 86.16396523373268 %
# Epoch [981/1000], Step [300/300], Loss: 0.1805
# Accuracy of the model on the 38311 samples: 85.58116467855186 %
# Accuracy of the model on the 38311 samples: 85.7064550651249 %
# Accuracy of the model on the 12771 samples: 86.07000234907211 %
# Accuracy of the model on the 12771 samples: 85.52188552188552 %
# Epoch [991/1000], Step [100/300], Loss: 0.2577
# Accuracy of the model on the 38311 samples: 86.5678264728146 %
# Accuracy of the model on the 12771 samples: 86.52415629159815 %
# Accuracy of the model on the 12771 samples: 86.61811917625872 %
# Epoch [991/1000], Step [200/300], Loss: 0.3399
# Accuracy of the model on the 38311 samples: 86.31202526689462 %
# Accuracy of the model on the 12771 samples: 86.24226763761648 %
# Accuracy of the model on the 12771 samples: 86.05434186829535 %
# Epoch [991/1000], Step [300/300], Loss: 0.2085
# Accuracy of the model on the 38311 samples: 85.80564328782856 %
# Accuracy of the model on the 12771 samples: 86.26575835878161 %
# Accuracy of the model on the 12771 samples: 85.77245321431369 %
# Epoch [992/1000], Step [100/300], Loss: 0.2541
# Accuracy of the model on the 38311 samples: 86.15802250006526 %
# Accuracy of the model on the 12771 samples: 86.68076109936575 %
# Accuracy of the model on the 12771 samples: 86.28141883955837 %
# Epoch [992/1000], Step [200/300], Loss: 0.3235
# Accuracy of the model on the 38311 samples: 86.36945002740727 %
# Accuracy of the model on the 12771 samples: 86.65727037820061 %
# Accuracy of the model on the 12771 samples: 86.13264427217915 %
# Epoch [992/1000], Step [300/300], Loss: 0.1914
# Accuracy of the model on the 38311 samples: 85.8761191302759 %
# Accuracy of the model on the 12771 samples: 86.25009787800485 %
# Accuracy of the model on the 12771 samples: 85.6471693680996 %
# Epoch [993/1000], Step [100/300], Loss: 0.2502
# Accuracy of the model on the 38311 samples: 86.3172456996685 %
# Accuracy of the model on the 12771 samples: 86.41453292616083 %
# Accuracy of the model on the 12771 samples: 86.33623052227703 %
# Epoch [993/1000], Step [200/300], Loss: 0.3607
# Accuracy of the model on the 38311 samples: 86.16324293283913 %
# Accuracy of the model on the 12771 samples: 86.33623052227703 %
# Accuracy of the model on the 12771 samples: 86.42236316654922 %
# Epoch [993/1000], Step [300/300], Loss: 0.1826
# Accuracy of the model on the 38311 samples: 85.68818355041633 %
# Accuracy of the model on the 12771 samples: 86.14047451256754 %
# Accuracy of the model on the 12771 samples: 85.5297157622739 %
# Epoch [994/1000], Step [100/300], Loss: 0.2296
# Accuracy of the model on the 38311 samples: 86.17890423116076 %
# Accuracy of the model on the 12771 samples: 86.20311643567457 %
# Accuracy of the model on the 12771 samples: 86.40670268577246 %
# Epoch [994/1000], Step [200/300], Loss: 0.3384
# Accuracy of the model on the 38311 samples: 86.14758163451751 %
# Accuracy of the model on the 12771 samples: 86.16396523373268 %
# Accuracy of the model on the 12771 samples: 86.13264427217915 %
# Epoch [994/1000], Step [300/300], Loss: 0.1870
# Accuracy of the model on the 38311 samples: 85.77171047479835 %
# Accuracy of the model on the 12771 samples: 86.14047451256754 %
# Accuracy of the model on the 12771 samples: 85.57669720460419 %
# Epoch [995/1000], Step [100/300], Loss: 0.2302
# Accuracy of the model on the 38311 samples: 86.10842838871342 %
# Accuracy of the model on the 12771 samples: 86.3518910030538 %
# Accuracy of the model on the 12771 samples: 86.01519066635346 %
# Epoch [995/1000], Step [200/300], Loss: 0.3453
# Accuracy of the model on the 38311 samples: 86.44775651901543 %
# Accuracy of the model on the 12771 samples: 86.48500508965625 %
# Accuracy of the model on the 12771 samples: 86.46151436849111 %
# Epoch [995/1000], Step [300/300], Loss: 0.2097
# Accuracy of the model on the 38311 samples: 85.91788259246691 %
# Accuracy of the model on the 12771 samples: 86.22660715683972 %
# Accuracy of the model on the 12771 samples: 85.69415081042987 %
# Epoch [996/1000], Step [100/300], Loss: 0.2549
# Accuracy of the model on the 38311 samples: 86.16585314922607 %
# Accuracy of the model on the 12771 samples: 86.49283533004463 %
# Accuracy of the model on the 12771 samples: 86.1561349933443 %
# Epoch [996/1000], Step [200/300], Loss: 0.3430
# Accuracy of the model on the 38311 samples: 86.05361384458772 %
# Accuracy of the model on the 12771 samples: 86.21094667606296 %
# Accuracy of the model on the 12771 samples: 86.21877691645133 %
# Epoch [996/1000], Step [300/300], Loss: 0.1631
# Accuracy of the model on the 38311 samples: 85.21312416799353 %
# Accuracy of the model on the 12771 samples: 85.6471693680996 %
# Accuracy of the model on the 12771 samples: 85.12254326207814 %
# Epoch [997/1000], Step [100/300], Loss: 0.2717
# Accuracy of the model on the 38311 samples: 85.88133956304978 %
# Accuracy of the model on the 12771 samples: 86.26575835878161 %
# Accuracy of the model on the 12771 samples: 85.93688826246965 %
# Epoch [997/1000], Step [200/300], Loss: 0.3673
# Accuracy of the model on the 38311 samples: 85.84479653363263 %
# Accuracy of the model on the 12771 samples: 85.97603946441156 %
# Accuracy of the model on the 12771 samples: 85.73330201237178 %
# Epoch [997/1000], Step [300/300], Loss: 0.1992
# Accuracy of the model on the 38311 samples: 85.8552373991804 %
# Accuracy of the model on the 12771 samples: 86.25009787800485 %
# Accuracy of the model on the 12771 samples: 85.61584840654608 %
# Epoch [998/1000], Step [100/300], Loss: 0.2656
# Accuracy of the model on the 38311 samples: 85.89700086137141 %
# Accuracy of the model on the 12771 samples: 85.9603789836348 %
# Accuracy of the model on the 12771 samples: 85.92905802208128 %
# Epoch [998/1000], Step [200/300], Loss: 0.3689
# Accuracy of the model on the 38311 samples: 86.08232622484404 %
# Accuracy of the model on the 12771 samples: 86.10132331062563 %
# Accuracy of the model on the 12771 samples: 86.17179547412105 %
# Epoch [998/1000], Step [300/300], Loss: 0.2089
# Accuracy of the model on the 38311 samples: 86.29636396857299 %
# Accuracy of the model on the 12771 samples: 86.67293085897737 %
# Accuracy of the model on the 12771 samples: 86.22660715683972 %
# Epoch [999/1000], Step [100/300], Loss: 0.2582
# Accuracy of the model on the 38311 samples: 86.52345279423665 %
# Accuracy of the model on the 12771 samples: 86.83736590713335 %
# Accuracy of the model on the 12771 samples: 86.30490956072352 %
# Epoch [999/1000], Step [200/300], Loss: 0.3583
# Accuracy of the model on the 38311 samples: 86.126699903422 %
# Accuracy of the model on the 12771 samples: 86.10132331062563 %
# Accuracy of the model on the 12771 samples: 86.43019340693759 %
# Epoch [999/1000], Step [300/300], Loss: 0.1887
# Accuracy of the model on the 38311 samples: 85.81347393698938 %
# Accuracy of the model on the 12771 samples: 86.08566282984887 %
# Accuracy of the model on the 12771 samples: 85.47490407955524 %
# Epoch [1000/1000], Step [100/300], Loss: 0.2523
# Accuracy of the model on the 38311 samples: 85.50546840333064 %
# Accuracy of the model on the 12771 samples: 85.6471693680996 %
# Accuracy of the model on the 12771 samples: 85.34962023334117 %
# Epoch [1000/1000], Step [200/300], Loss: 0.3525
# Accuracy of the model on the 38311 samples: 86.41382370598522 %
# Accuracy of the model on the 12771 samples: 86.43019340693759 %
# Accuracy of the model on the 12771 samples: 86.45368412810274 %
# Epoch [1000/1000], Step [300/300], Loss: 0.1810
# Accuracy of the model on the 38311 samples: 86.03534232987914 %
# Accuracy of the model on the 12771 samples: 86.51632605120977 %
# Accuracy of the model on the 12771 samples: 86.06217210868374 %

# %%
# Test the model
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in val_iterator:
        images = images.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print(f'Val Accuracy of the model on the {len(y_val)} val images: {100 * correct / total} %') 
            
# Test the model
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_iterator:
        images = images.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print(f'Test Accuracy of the model on the {len(y_test)} test images: {100 * correct / total} %')

# %%
print(model)
# Out:
# RNN(
#   (lstm): LSTM(28, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
from torchviz import make_dot

dum_input = torch.ones(1,28,28).to(device)
a = model(dum_input)
make_dot(a, params=dict(model.named_parameters())).render(f"{model_save_dir}viz/lstm-{num_epochs}epochs-{num_layers}layers-{hidden_size}hidden",format="png")
# Out:
# '/home/hwixley/Documents/4th-Year/Honours-Project/localhost-data-preprocessing/ml-models/db16/polar-lag0/viz/lstm-1000epochs-2layers-128hidden.png'

# %%
train_rnn = []
val_rnn = []
test_rnn = []
loss_rnn = []

for i in range(num_epochs):
    ep = epochs[i]
    train_rnn.append(ep["train"][2])
    val_rnn.append(ep["val"][2])
    test_rnn.append(ep["test"][2])
    loss_rnn.append(ep["loss"])

# %%
epochs = np.arange(0,num_epochs,1)

plt.plot(epochs, train_rnn, c="r", lw=0.7, label="Train")
plt.plot(epochs, val_rnn, c="b", lw=0.7, label="Validation")
plt.plot(epochs, test_rnn, c="g", lw=0.7, label="Test")
plt.grid(True)
plt.legend(loc="upper right")
plt.title("LSTM RNN (polar features, lag 0) - Epoch vs. Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch #")
# Out:
# Text(0.5, 0, 'Epoch #')

# %% [markdown]
# # Neural Net

# %%
from numpy import vstack
from pandas import read_csv
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.utils.data import random_split
from torch import Tensor
from torch.nn import Linear
from torch.nn import ReLU
from torch.nn import Sigmoid
from torch.nn import Module
from torch.optim import SGD
from torch.nn import BCELoss
from torch.nn.init import kaiming_uniform_
from torch.nn.init import xavier_uniform_

# model definition
class MLP(Module):
    # define model elements
    def __init__(self, n_inputs):
        super(MLP, self).__init__()
        # input to first hidden layer
        self.hidden1 = Linear(n_inputs, 600).to(device)
        kaiming_uniform_(self.hidden1.weight, nonlinearity='relu').to(device)
        self.act1 = ReLU()
        # second hidden layer
        self.hidden2 = Linear(600, 500).to(device)
        kaiming_uniform_(self.hidden2.weight, nonlinearity='relu').to(device)
        self.act2 = ReLU()
        # third hidden layer and output
        self.hidden3 = Linear(500, 300).to(device)
        kaiming_uniform_(self.hidden3.weight, nonlinearity='relu').to(device)
        self.act3 = ReLU()
        #
        self.hidden4 = Linear(300, 150).to(device)
        kaiming_uniform_(self.hidden4.weight, nonlinearity='relu').to(device)
        self.act4 = ReLU()
        #
        self.hidden5 = Linear(150, 1).to(device)
        xavier_uniform_(self.hidden5.weight).to(device)
        self.act5 = Sigmoid()
        
 
    # forward propagate input
    def forward(self, X):
        # input to first hidden layer
        X = self.hidden1(X)
        X = self.act1(X)
         # second hidden layer
        X = self.hidden2(X)
        X = self.act2(X)
        # third hidden layer and output
        X = self.hidden3(X)
        X = self.act3(X)
        #
        X = self.hidden4(X)
        X = self.act4(X)
        #
        X = self.hidden5(X)
        X = self.act5(X)
        return X

# train the model
def train_model(train_dl, model):
    # define the optimization
    criterion = BCELoss()
    optimizer = SGD(model.parameters(), lr=0.01, momentum=0.9)
    # enumerate epochs
    for epoch in tqdm(range(100)):
        # enumerate mini batches
        for i, (inputs, targets) in enumerate(train_dl):
            # clear the gradients
            optimizer.zero_grad()
            # compute the model output
            yhat = model(inputs.to(device))
            # calculate loss
            #print(yhat.shape)
            loss = criterion(yhat, targets.reshape(-1,1).to(device))
            print(f"epoch {i}: loss {loss}")
            # credit assignment
            loss.backward()
            # update model weights
            optimizer.step()

            
# evaluate the model
def evaluate_model(test_dl, model):
    predictions, actuals = list(), list()
    for i, (inputs, targets) in enumerate(test_dl):
        # evaluate the model on the test set
        yhat = model(inputs.to(device)).cpu()
        # retrieve numpy array
        yhat = yhat.detach().numpy()
        actual = targets.numpy()
        actual = actual.reshape((len(actual), 1))
        # round to class values
        yhat = yhat.round()
        # store
        predictions.append(yhat)
        actuals.append(actual)
    predictions, actuals = vstack(predictions), vstack(actuals)
    # calculate accuracy
    acc = accuracy_score(actuals, predictions)
    return acc
 
# make a class prediction for one row of data
def predict(row, model):
    # convert row to data
    row = Tensor([row])
    # make prediction
    yhat = model(row)
    # retrieve numpy array
    yhat = yhat.cpu().detach().numpy()
    return yhat
 
# define the network
model = MLP(784)
# train the model
train_model(train_iterator, model)
# evaluate the model
acc = evaluate_model(val_iterator, model)
print('Accuracy: %.3f' % acc)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# epoch 0: loss 0.5500611662864685
# epoch 1: loss 0.4101846218109131
# epoch 2: loss 0.5257068276405334
# epoch 3: loss 0.6833233833312988
# epoch 4: loss 0.45541390776634216
# epoch 5: loss 0.3435070216655731
# epoch 6: loss 0.40591639280319214
# epoch 7: loss 0.38531774282455444
# epoch 8: loss 0.474290132522583
# epoch 9: loss 0.49090608954429626
# epoch 10: loss 0.4676029086112976
# epoch 11: loss 0.4214766025543213
# epoch 12: loss 0.38312554359436035
# epoch 13: loss 0.5094064474105835
# epoch 14: loss 0.4004752039909363
# epoch 15: loss 0.4089033007621765
# epoch 16: loss 0.37904679775238037
# epoch 17: loss 0.4463964104652405
# epoch 18: loss 0.486097514629364
# epoch 19: loss 0.3884008824825287
# epoch 20: loss 0.4015762507915497
# epoch 21: loss 0.3920731544494629
# epoch 22: loss 0.4037277102470398
# epoch 100: loss 0.5075240135192871
# epoch 101: loss 0.31130707263946533
# epoch 102: loss 0.26049748063087463
# epoch 103: loss 0.28551316261291504
# epoch 104: loss 0.24830281734466553
# epoch 105: loss 0.36562108993530273
# epoch 106: loss 0.3118049204349518
# epoch 107: loss 0.26631075143814087
# epoch 108: loss 0.3367115259170532
# epoch 109: loss 0.3483824133872986
# epoch 110: loss 0.33785372972488403
# epoch 111: loss 0.3570496141910553
# epoch 112: loss 0.3749545216560364
# epoch 113: loss 0.2853526771068573
# epoch 114: loss 0.17044630646705627
# epoch 115: loss 0.4057011306285858
# epoch 116: loss 0.29723697900772095
# epoch 117: loss 0.25439658761024475
# epoch 118: loss 0.3160704970359802
# epoch 119: loss 0.3780367374420166
# epoch 120: loss 0.2590208649635315
# epoch 121: loss 0.3723211884498596
# epoch 122: loss 0.24267154932022095
# epoch 123: loss 0.3677777349948883
# epoch 124: loss 0.3334972560405731
# epoch 125: loss 0.3405730724334717
# epoch 126: loss 0.3767406642436981
# epoch 127: loss 0.42551204562187195
# epoch 128: loss 0.28741464018821716
# epoch 129: loss 0.3426315188407898
# epoch 130: loss 0.43487298488616943
# epoch 131: loss 0.3491353988647461
# epoch 132: loss 0.3702620267868042
# epoch 133: loss 0.3865869343280792
# epoch 134: loss 0.3214275538921356
# epoch 135: loss 0.26551786065101624
# epoch 136: loss 0.24608910083770752
# Accuracy: 0.874

# %%
SEED = 1234

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
class VGG(nn.Module):
    def __init__(self, features, output_dim):
        super().__init__()

        self.features = features

        self.avgpool = nn.AdaptiveAvgPool2d(7)

        self.classifier = nn.Sequential(
            nn.Linear(512 * 7 * 7, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(4096, output_dim),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        h = x.view(x.shape[0], -1)
        x = self.classifier(h)
        return x, h

# %%
vgg11_config = [6, 'M', 12, 'M', 24, 24, 'M']#[64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M']

vgg13_config = [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512,
                512, 'M']

vgg16_config = [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512,
                'M', 512, 512, 512, 'M']

vgg19_config = [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512,
                512, 512, 'M', 512, 512, 512, 512, 'M']

# %%
def get_vgg_layers(config, batch_norm):

    layers = []
    in_channels = 3

    for c in config:
        assert c == 'M' or isinstance(c, int)
        if c == 'M':
            layers += [nn.MaxPool2d(kernel_size=2)]
        else:
            conv2d = nn.Conv2d(in_channels, c, kernel_size=3, padding=1)
            if batch_norm:
                layers += [conv2d, nn.BatchNorm2d(c), nn.ReLU(inplace=True)]
            else:
                layers += [conv2d, nn.ReLU(inplace=True)]
            in_channels = c

    return nn.Sequential(*layers)

# %%
vgg11_layers = get_vgg_layers(vgg11_config, batch_norm=True)

# %%
OUTPUT_DIM = 2

model = VGG(vgg11_layers, OUTPUT_DIM)

print(model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(6, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace=True)
#     (11): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU(inplace=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=7)
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ## TRAINING

# %%
START_LR = 1e-7

optimizer = optim.Adam(model.parameters(), lr=START_LR)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

criterion = nn.CrossEntropyLoss()

model = model.to(device)
criterion = criterion.to(device)

# %%
class LRFinder:
    def __init__(self, model, optimizer, criterion, device):

        self.optimizer = optimizer
        self.model = model
        self.criterion = criterion
        self.device = device

        torch.save(model.state_dict(), 'init_params.pt')

    def range_test(self, iterator, end_lr=10, num_iter=100,
                   smooth_f=0.05, diverge_th=5):

        lrs = []
        losses = []
        best_loss = float('inf')

        lr_scheduler = ExponentialLR(self.optimizer, end_lr, num_iter)

        iterator = IteratorWrapper(iterator)

        for iteration in range(num_iter):

            loss = self._train_batch(iterator)

            lrs.append(lr_scheduler.get_last_lr()[0])

            # update lr
            lr_scheduler.step()

            if iteration > 0:
                loss = smooth_f * loss + (1 - smooth_f) * losses[-1]

            if loss < best_loss:
                best_loss = loss

            losses.append(loss)

            if loss > diverge_th * best_loss:
                print("Stopping early, the loss has diverged")
                break

        # reset model to initial parameters
        model.load_state_dict(torch.load('init_params.pt'))

        return lrs, losses

    def _train_batch(self, iterator):

        self.model.train()

        self.optimizer.zero_grad()

        x, y = iterator.get_batch()

        x = x.to(self.device)
        y = y.to(self.device)

        y_pred, _ = self.model(x)

        loss = self.criterion(y_pred, y)

        loss.backward()

        self.optimizer.step()

        return loss.item()


class ExponentialLR(_LRScheduler):
    def __init__(self, optimizer, end_lr, num_iter, last_epoch=-1):
        self.end_lr = end_lr
        self.num_iter = num_iter
        super(ExponentialLR, self).__init__(optimizer, last_epoch)

    def get_lr(self):
        curr_iter = self.last_epoch
        r = curr_iter / self.num_iter
        return [base_lr * (self.end_lr / base_lr) ** r for base_lr in
                self.base_lrs]


class IteratorWrapper:
    def __init__(self, iterator):
        self.iterator = iterator
        self._iterator = iter(iterator)

    def __next__(self):
        try:
            inputs, labels = next(self._iterator)
        except StopIteration:
            self._iterator = iter(self.iterator)
            inputs, labels, *_ = next(self._iterator)

        return inputs, labels

    def get_batch(self):
        return next(self)

# %%
END_LR = 10
NUM_ITER = 100

lr_finder = LRFinder(model, optimizer, criterion, device)
lrs, losses = lr_finder.range_test(train_iterator, END_LR, NUM_ITER)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_20757/2487619677.py in <module>
#       3
#       4 lr_finder = LRFinder(model, optimizer, criterion, device)
# ----> 5 lrs, losses = lr_finder.range_test(train_iterator, END_LR, NUM_ITER)
#
# /tmp/ipykernel_20757/3766690282.py in range_test(self, iterator, end_lr, num_iter, smooth_f, diverge_th)
#      22         for iteration in range(num_iter):
#      23
# ---> 24             loss = self._train_batch(iterator)
#      25
#      26             lrs.append(lr_scheduler.get_last_lr()[0])
#
# /tmp/ipykernel_20757/3766690282.py in _train_batch(self, iterator)
#      57         y = y.to(self.device)
#      58
# ---> 59         y_pred, _ = self.model(x)
#      60
#      61         loss = self.criterion(y_pred, y)
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /tmp/ipykernel_20757/1629760926.py in forward(self, x)
#      18
#      19     def forward(self, x):
# ---> 20         x = self.features(x)
#      21         x = self.avgpool(x)
#      22         h = x.view(x.shape[0], -1)
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/pooling.py in forward(self, input)
#     160
#     161     def forward(self, input: Tensor):
# --> 162         return F.max_pool2d(input, self.kernel_size, self.stride,
#     163                             self.padding, self.dilation, self.ceil_mode,
#     164                             self.return_indices)
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/_jit_internal.py in fn(*args, **kwargs)
#     420             return if_true(*args, **kwargs)
#     421         else:
# --> 422             return if_false(*args, **kwargs)
#     423
#     424     if if_true.__doc__ is None and if_false.__doc__ is not None:
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/functional.py in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     781     if stride is None:
#     782         stride = torch.jit.annotate(List[int], [])
# --> 783     return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#     784
#     785
#
# RuntimeError: Given input size: (12x1x1). Calculated output size: (12x0x0). Output size is too small
