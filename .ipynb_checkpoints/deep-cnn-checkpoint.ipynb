# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import _LRScheduler
import torch.utils.data as data
from torch.utils.data import TensorDataset, DataLoader

import torchvision.transforms as transforms
import torchvision.datasets as datasets

from sklearn import decomposition
from sklearn import manifold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from tqdm.notebook import tqdm, trange
import matplotlib.pyplot as plt
import numpy as np

import copy
import random
import time
import os

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
features = "polar"
lag = "0"
model_save_dir = os.getcwd() + f"/ml-models/{features}-lag{lag}/"

# %%
def loadNpy(filename):
    with open(os.getcwd() + "/train-val-test/"+ filename, "rb") as f: return np.load(f)

db = f"db14/window-size-10/lag{lag}/{features}-features/"
data_type = ""

# %%
DIR = os.getcwd() + "/train-val-test/" + db

# %%
X_train, X_val, X_test = loadNpy(db + f"X_train.npy"), loadNpy(db + f"X_val.npy"), loadNpy(db + f"X_test.npy")
y_train, y_val, y_test = loadNpy(db + f"y{data_type}_train.npy"), loadNpy(db + f"y{data_type}_val.npy"), loadNpy(db + f"y{data_type}_test.npy")

# %%
def npy_to_tensor(data, l=False):
    if not l:
        data = torch.from_numpy(data).float()
    else:
        data = torch.from_numpy(data).type(torch.LongTensor)
    return data

# %%
X_train, X_val, X_test = npy_to_tensor(X_train), npy_to_tensor(X_val), npy_to_tensor(X_test)
y_train, y_val, y_test = npy_to_tensor(y_train,1), npy_to_tensor(y_val,1), npy_to_tensor(y_test,1)

# %%
batch_size = 128

# %%
train_dataset = TensorDataset(X_train, y_train)

val_dataset = TensorDataset(X_val, y_val)

test_dataset = TensorDataset(X_test, y_test)

# Data loader
train_iterator = DataLoader(dataset=train_dataset,batch_size=batch_size,shuffle=False)

val_iterator = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)

test_iterator = DataLoader(dataset=test_dataset, batch_size=batch_size,shuffle=False)

# %%
torch.save(train_dataset, DIR + "train-dataset")
torch.save(val_dataset, DIR + "val-dataset")
torch.save(test_dataset, DIR + "test-dataset")

# %%
X_train.shape
# Out:
# torch.Size([17505, 1, 28, 28])

# %%
X_val.shape
# Out:
# torch.Size([5835, 1, 28, 28])

# %%
input_size = val_iterator
# Out:
# 28

# %%
X_train.dtype
# Out:
# torch.float32

# %%
def eval_net(mod, data):
    preds = []
    actual = []
    
    shape = data.dataset.tensors[0].shape[1:]
    print(shape)
    
    mod.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in data:
            if len(shape) == 2:
                images = images.reshape(-1, shape[0], shape[1]).to(device)
            else:
                images = images.reshape(-1, shape[0], shape[1], shape[2])
            labels = labels.to(device)
            outputs = mod(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            preds.append(predicted)
            actual.append(labels)

        print(f'Accuracy of the model on the {total} samples: {100 * correct / total} %')
    return preds, actual, correct/total

# %% [markdown]
# # CNN

# %%
loaders = {
    'train': train_iterator,
    'val': val_iterator,
    'test': test_iterator
}

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(         
            nn.Conv2d(
                in_channels=1,              
                out_channels=16,            
                kernel_size=5,              
                stride=1,                   
                padding=2,                  
            ),                              
            nn.ReLU(),                      
            nn.MaxPool2d(kernel_size=2),    
        )
        self.conv2 = nn.Sequential(         
            nn.Conv2d(16, 32, 5, 1, 2),     
            nn.ReLU(),                      
            nn.MaxPool2d(2),                
        )
        self.conv3 = nn.Sequential(         
            nn.Conv2d(32, 64, 5, 1, 2),     
            nn.ReLU()               
        )
        # fully connected layer, output 10 classes
        self.out = nn.Linear(64 * 7 * 7, 2)
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        # flatten the output of conv2 to (batch_size, 32 * 7 * 7)
        x = x.view(x.size(0), -1)       
        output = self.out(x)
        return output, x    # return x for visualization

# %%
cnn = CNN()
print(cnn)
# Out:
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#   )
#   (out): Linear(in_features=3136, out_features=2, bias=True)
# )

# %%
loss_func = nn.CrossEntropyLoss()   
loss_func
# Out:
# CrossEntropyLoss()

# %%
optimizer = optim.Adam(cnn.parameters(), lr = 0.001)   
optimizer
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )

# %%
from torch.autograd import Variable

num_epochs = 1000
cnn_epochs = {}

def train(num_epochs, cnn, loaders):
    
    cnn.train()
        
    # Train the model
    total_step = len(loaders['train'])
        
    for epoch in range(num_epochs):
        for i, (images, labels) in enumerate(loaders['train']):
            
            # gives batch data, normalize x when iterate train_loader
            b_x = Variable(images)   # batch x
            b_y = Variable(labels)   # batch y
            output = cnn(b_x)[0]               
            loss = loss_func(output, b_y)
            
            # clear gradients for this training step   
            optimizer.zero_grad()           
            
            # backpropagation, compute gradients 
            loss.backward()    
            # apply gradients             
            optimizer.step()                
            
            if (i+1) % 100 == 0:
                print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'.format(epoch + 1, num_epochs, i + 1, total_step, loss.item()))
                cnn_epochs[epoch] = {"loss": loss.item(), "train": eval_net(cnn, train_iterator), 
                             "val": eval_cnn(cnn, val_iterator), "test": eval_cnn(cnn, test_iterator)}
                cnn.train()
                pass
        pass
    pass

train(num_epochs, cnn, loaders)
# Out:
# Epoch [1/1000], Step [100/137], Loss: 0.4289
# torch.Size([1, 28, 28])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5719/703504599.py in <module>
#      37     pass
#      38
# ---> 39 train(num_epochs, cnn, loaders)
#
# /tmp/ipykernel_5719/703504599.py in train(num_epochs, cnn, loaders)
#      30             if (i+1) % 100 == 0:
#      31                 print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'.format(epoch + 1, num_epochs, i + 1, total_step, loss.item()))
# ---> 32                 cnn_epochs[epoch] = {"loss": loss.item(), "train": eval_net(cnn, train_iterator),
#      33                              "val": eval_cnn(cnn, val_iterator), "test": eval_cnn(cnn, test_iterator)}
#      34                 cnn.train()
#
# /tmp/ipykernel_5719/2532989991.py in eval_net(mod, data)
#      17             labels = labels.to(device)
#      18             outputs = mod(images)
# ---> 19             _, predicted = torch.max(outputs, 1)
#      20             total += labels.size(0)
#      21             correct += (predicted == labels).sum().item()
#
# TypeError: max() received an invalid combination of arguments - got (tuple, int), but expected one of:
#  * (Tensor input)
#  * (Tensor input, Tensor other, *, Tensor out)
#  * (Tensor input, int dim, bool keepdim, *, tuple of Tensors out)
#  * (Tensor input, name dim, bool keepdim, *, tuple of Tensors out)

# %%
from torchmetrics import ROC

def eval_cnn(data):
    # Test the model
    fps = []
    
    cnn.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        pred_ys = []
        labs = []
        for images, labels in loaders[data]:
            test_output, last_layer = cnn(images)
            pred_y = torch.max(test_output, 1)[1].data.squeeze()
            pred_ys = pred_ys + test_output.flatten().tolist()
            labs = labs + labels.tolist()
            total += len(labels)
            correct += (pred_y == labels).sum().item()
            pass
        print(f'{data} Accuracy of the model on the {total} {data} images: %.3f' % (correct/total))
    pass

# %%
eval_cnn("val")
eval_cnn("test")
# Out:
# val Accuracy of the model on the 5835 val images: 0.896
# test Accuracy of the model on the 5835 test images: 0.898

# %%
roc = ROC(num_classes=2)
fpr, tpr, thresholds = roc(torch.FloatTensor(pred_ys), torch.FloatTensor(labs))

# %%
from torchviz import make_dot

dum_input = torch.ones(1,1,28,28)
a, b = cnn(dum_input)
make_dot(a, params=dict(cnn.named_parameters())).render(f"{model_save_dir}viz/cnn-{num_epochs}epochs-crossEnt-adamOpt",format="png")
# Out:
# '/home/hwixley/Documents/4th-Year/Honours-Project/localhost-data-preprocessing/ml-models/polar-lag0/viz/cnn-50epochs-crossEnt-adamOpt.png'

# %% [markdown]
# ## CORE ML

# %% [markdown]
# ## ONNX

# %%
import onnx

# %%
cnn.eval()
dummy_input = torch.randn(1, 1, 28, 28)
input_names = [ "actual_input" ]
output_names = [ "output" ]
model = cnn

# %%
torch.onnx.export(model, 
                  dummy_input,
                  "polar-window10-lag0-cnn.onnx",
                  verbose=False,
                  input_names=input_names,
                  output_names=output_names,
                  export_params=True,
                  )

# %% [markdown]
# # LSTM

# %%
# Hyper-parameters
sequence_length = 28
input_size = 28
hidden_size = 128
num_layers = 2
num_classes = 2
batch_size = 128
num_epochs = 1000
learning_rate = 0.01

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x):
        # Set initial hidden and cell states 
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) 
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        
        # Forward propagate LSTM
        out, _ = self.lstm(x, (h0, c0))  # out: tensor of shape (batch_size, seq_length, hidden_size)
        
        # Decode the hidden state of the last time step
        out = self.fc(out[:, -1, :])
        return out

# %%
epochs = {}

# %%
model = RNN(input_size, hidden_size, num_layers, num_classes).to(device)


# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Train the model
total_step = len(train_iterator)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_iterator):
        images = images.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
            epochs[epoch] = {"loss": loss.item(), "train": eval_rnn(model, train_iterator), 
                             "val": eval_rnn(model, val_iterator), "test": eval_rnn(model, test_iterator)}
            
            model.train()
# Out:
# Epoch [1/1000], Step [100/137], Loss: 0.4097
# Accuracy of the model on the 17505 samples: 86.12967723507569 %
# Accuracy of the model on the 5835 samples: 85.48414738646102 %
# Accuracy of the model on the 5835 samples: 86.0325621251071 %
# Epoch [2/1000], Step [100/137], Loss: 0.4079
# Accuracy of the model on the 17505 samples: 86.12967723507569 %
# Accuracy of the model on the 5835 samples: 85.48414738646102 %
# Accuracy of the model on the 5835 samples: 86.0325621251071 %
# Epoch [3/1000], Step [100/137], Loss: 0.3593
# Accuracy of the model on the 17505 samples: 86.51242502142244 %
# Accuracy of the model on the 5835 samples: 86.32390745501286 %
# Accuracy of the model on the 5835 samples: 86.28963153384747 %
# Epoch [4/1000], Step [100/137], Loss: 0.3601
# Accuracy of the model on the 17505 samples: 86.3638960297058 %
# Accuracy of the model on the 5835 samples: 85.79263067694944 %
# Accuracy of the model on the 5835 samples: 86.46101113967438 %
# Epoch [5/1000], Step [100/137], Loss: 0.3535
# Accuracy of the model on the 17505 samples: 86.50671236789489 %
# Accuracy of the model on the 5835 samples: 86.18680377035133 %
# Accuracy of the model on the 5835 samples: 86.7866323907455 %
# Epoch [6/1000], Step [100/137], Loss: 0.3590
# Accuracy of the model on the 17505 samples: 86.30676949443016 %
# Accuracy of the model on the 5835 samples: 86.2210796915167 %
# Accuracy of the model on the 5835 samples: 86.75235646958012 %
# Epoch [7/1000], Step [100/137], Loss: 0.3479
# Accuracy of the model on the 17505 samples: 86.68951728077693 %
# Accuracy of the model on the 5835 samples: 86.54670094258783 %
# Accuracy of the model on the 5835 samples: 86.51242502142244 %
# Epoch [8/1000], Step [100/137], Loss: 0.3466
# Accuracy of the model on the 17505 samples: 86.85518423307626 %
# Accuracy of the model on the 5835 samples: 86.34104541559554 %
# Accuracy of the model on the 5835 samples: 86.85518423307626 %
# Epoch [9/1000], Step [100/137], Loss: 0.3470
# Accuracy of the model on the 17505 samples: 86.86660954013139 %
# Accuracy of the model on the 5835 samples: 86.426735218509 %
# Accuracy of the model on the 5835 samples: 86.76949443016281 %
# Epoch [10/1000], Step [100/137], Loss: 0.3411
# Accuracy of the model on the 17505 samples: 87.32362182233648 %
# Accuracy of the model on the 5835 samples: 86.87232219365896 %
# Accuracy of the model on the 5835 samples: 87.31790916880891 %
# Epoch [11/1000], Step [100/137], Loss: 0.3416
# Accuracy of the model on the 17505 samples: 86.90659811482433 %
# Accuracy of the model on the 5835 samples: 86.44387317909168 %
# Accuracy of the model on the 5835 samples: 86.70094258783205 %
# Epoch [12/1000], Step [100/137], Loss: 0.3397
# Accuracy of the model on the 17505 samples: 87.66066838046272 %
# Accuracy of the model on the 5835 samples: 87.40359897172236 %
# Accuracy of the model on the 5835 samples: 87.24935732647815 %
# Epoch [13/1000], Step [100/137], Loss: 0.3422
# Accuracy of the model on the 17505 samples: 87.2093687517852 %
# Accuracy of the model on the 5835 samples: 86.85518423307626 %
# Accuracy of the model on the 5835 samples: 86.94087403598972 %
# Epoch [14/1000], Step [100/137], Loss: 0.3393
# Accuracy of the model on the 17505 samples: 87.40359897172236 %
# Accuracy of the model on the 5835 samples: 87.00942587832049 %
# Accuracy of the model on the 5835 samples: 86.9751499571551 %
# Epoch [15/1000], Step [100/137], Loss: 0.3344
# Accuracy of the model on the 17505 samples: 87.51785204227363 %
# Accuracy of the model on the 5835 samples: 86.99228791773778 %
# Accuracy of the model on the 5835 samples: 87.26649528706083 %
# Epoch [16/1000], Step [100/137], Loss: 0.3352
# Accuracy of the model on the 17505 samples: 87.59211653813196 %
# Accuracy of the model on the 5835 samples: 87.00942587832049 %
# Accuracy of the model on the 5835 samples: 87.38646101113967 %
# Epoch [17/1000], Step [100/137], Loss: 0.3409
# Accuracy of the model on the 17505 samples: 87.74064552984862 %
# Accuracy of the model on the 5835 samples: 87.21508140531277 %
# Accuracy of the model on the 5835 samples: 87.66066838046272 %
# Epoch [18/1000], Step [100/137], Loss: 0.3174
# Accuracy of the model on the 17505 samples: 88.16338189088832 %
# Accuracy of the model on the 5835 samples: 87.28363324764354 %
# Accuracy of the model on the 5835 samples: 87.69494430162811 %
# Epoch [19/1000], Step [100/137], Loss: 0.3296
# Accuracy of the model on the 17505 samples: 88.19194515852614 %
# Accuracy of the model on the 5835 samples: 87.54070265638389 %
# Accuracy of the model on the 5835 samples: 87.83204798628964 %
# Epoch [20/1000], Step [100/137], Loss: 0.3246
# Accuracy of the model on the 17505 samples: 87.71779491573837 %
# Accuracy of the model on the 5835 samples: 86.92373607540702 %
# Accuracy of the model on the 5835 samples: 87.02656383890317 %
# Epoch [21/1000], Step [100/137], Loss: 0.3453
# Accuracy of the model on the 17505 samples: 86.86089688660383 %
# Accuracy of the model on the 5835 samples: 86.426735218509 %
# Accuracy of the model on the 5835 samples: 87.21508140531277 %
# Epoch [22/1000], Step [100/137], Loss: 0.3363
# Accuracy of the model on the 17505 samples: 88.20908311910883 %
# Accuracy of the model on the 5835 samples: 87.60925449871465 %
# Accuracy of the model on the 5835 samples: 87.81491002570694 %
# Epoch [23/1000], Step [100/137], Loss: 0.3355
# Accuracy of the model on the 17505 samples: 87.67780634104541 %
# Accuracy of the model on the 5835 samples: 87.36932305055699 %
# Accuracy of the model on the 5835 samples: 87.7120822622108 %
# Epoch [24/1000], Step [100/137], Loss: 0.3435
# Accuracy of the model on the 17505 samples: 88.35189945729792 %
# Accuracy of the model on the 5835 samples: 87.59211653813196 %
# Accuracy of the model on the 5835 samples: 87.84918594687232 %
# Epoch [25/1000], Step [100/137], Loss: 0.3260
# Accuracy of the model on the 17505 samples: 88.30048557554984 %
# Accuracy of the model on the 5835 samples: 87.60925449871465 %
# Accuracy of the model on the 5835 samples: 87.72922022279349 %
# Epoch [26/1000], Step [100/137], Loss: 0.3277
# Accuracy of the model on the 17505 samples: 88.5575549842902 %
# Accuracy of the model on the 5835 samples: 87.9005998286204 %
# Accuracy of the model on the 5835 samples: 87.81491002570694 %
# Epoch [27/1000], Step [100/137], Loss: 0.3241
# Accuracy of the model on the 17505 samples: 88.66609540131391 %
# Accuracy of the model on the 5835 samples: 87.95201371036846 %
# Accuracy of the model on the 5835 samples: 88.0719794344473 %
# Epoch [28/1000], Step [100/137], Loss: 0.3300
# Accuracy of the model on the 17505 samples: 88.63181948014852 %
# Accuracy of the model on the 5835 samples: 87.8834618680377 %
# Accuracy of the model on the 5835 samples: 87.78063410454156 %
# Epoch [29/1000], Step [100/137], Loss: 0.3181
# Accuracy of the model on the 17505 samples: 88.79748643244787 %
# Accuracy of the model on the 5835 samples: 87.74635818337617 %
# Accuracy of the model on the 5835 samples: 87.79777206512425 %
# Epoch [30/1000], Step [100/137], Loss: 0.3156
# Accuracy of the model on the 17505 samples: 88.83747500714081 %
# Accuracy of the model on the 5835 samples: 87.78063410454156 %
# Accuracy of the model on the 5835 samples: 88.12339331619538 %
# Epoch [31/1000], Step [100/137], Loss: 0.3242
# Accuracy of the model on the 17505 samples: 88.75749785775493 %
# Accuracy of the model on the 5835 samples: 87.78063410454156 %
# Accuracy of the model on the 5835 samples: 87.98628963153385 %
# Epoch [32/1000], Step [100/137], Loss: 0.3127
# Accuracy of the model on the 17505 samples: 88.9174521565267 %
# Accuracy of the model on the 5835 samples: 87.9005998286204 %
# Accuracy of the model on the 5835 samples: 88.08911739502999 %
# Epoch [33/1000], Step [100/137], Loss: 0.3231
# Accuracy of the model on the 17505 samples: 88.84890031419594 %
# Accuracy of the model on the 5835 samples: 87.64353041988004 %
# Accuracy of the model on the 5835 samples: 87.93487574978577 %
# Epoch [34/1000], Step [100/137], Loss: 0.3200
# Accuracy of the model on the 17505 samples: 88.83747500714081 %
# Accuracy of the model on the 5835 samples: 87.84918594687232 %
# Accuracy of the model on the 5835 samples: 88.0719794344473 %
# Epoch [35/1000], Step [100/137], Loss: 0.3240
# Accuracy of the model on the 17505 samples: 88.70037132247928 %
# Accuracy of the model on the 5835 samples: 88.00342759211654 %
# Accuracy of the model on the 5835 samples: 88.00342759211654 %
# Epoch [36/1000], Step [100/137], Loss: 0.3146
# Accuracy of the model on the 17505 samples: 89.19737217937733 %
# Accuracy of the model on the 5835 samples: 88.46615252784919 %
# Accuracy of the model on the 5835 samples: 88.63753213367609 %
# Epoch [37/1000], Step [100/137], Loss: 0.3122
# Accuracy of the model on the 17505 samples: 88.95744073121965 %
# Accuracy of the model on the 5835 samples: 88.10625535561269 %
# Accuracy of the model on the 5835 samples: 88.58611825192801 %
# Epoch [38/1000], Step [100/137], Loss: 0.3087
# Accuracy of the model on the 17505 samples: 89.0431305341331 %
# Accuracy of the model on the 5835 samples: 88.19194515852614 %
# Accuracy of the model on the 5835 samples: 88.51756640959726 %
# Epoch [39/1000], Step [100/137], Loss: 0.3043
# Accuracy of the model on the 17505 samples: 89.19737217937733 %
# Accuracy of the model on the 5835 samples: 88.36332476435304 %
# Accuracy of the model on the 5835 samples: 88.70608397600685 %
# Epoch [40/1000], Step [100/137], Loss: 0.3018
# Accuracy of the model on the 17505 samples: 89.14024564410168 %
# Accuracy of the model on the 5835 samples: 88.34618680377035 %
# Accuracy of the model on the 5835 samples: 88.63753213367609 %
# Epoch [41/1000], Step [100/137], Loss: 0.2945
# Accuracy of the model on the 17505 samples: 89.2316481005427 %
# Accuracy of the model on the 5835 samples: 88.51756640959726 %
# Accuracy of the model on the 5835 samples: 88.74035989717224 %
# Epoch [42/1000], Step [100/137], Loss: 0.3029
# Accuracy of the model on the 17505 samples: 89.3116252499286 %
# Accuracy of the model on the 5835 samples: 88.10625535561269 %
# Accuracy of the model on the 5835 samples: 88.60325621251071 %
# Epoch [43/1000], Step [100/137], Loss: 0.3230
# Accuracy of the model on the 17505 samples: 89.07169380177092 %
# Accuracy of the model on the 5835 samples: 88.22622107969151 %
# Accuracy of the model on the 5835 samples: 88.87746358183377 %
# Epoch [44/1000], Step [100/137], Loss: 0.3101
# Accuracy of the model on the 17505 samples: 89.16309625821194 %
# Accuracy of the model on the 5835 samples: 88.53470437017995 %
# Accuracy of the model on the 5835 samples: 88.63753213367609 %
# Epoch [45/1000], Step [100/137], Loss: 0.3161
# Accuracy of the model on the 17505 samples: 89.34590117109397 %
# Accuracy of the model on the 5835 samples: 88.22622107969151 %
# Accuracy of the model on the 5835 samples: 88.75749785775493 %
# Epoch [46/1000], Step [100/137], Loss: 0.2875
# Accuracy of the model on the 17505 samples: 89.27734932876321 %
# Accuracy of the model on the 5835 samples: 88.67180805484148 %
# Accuracy of the model on the 5835 samples: 89.10025706940874 %
# Epoch [47/1000], Step [100/137], Loss: 0.3233
# Accuracy of the model on the 17505 samples: 89.18594687232219 %
# Accuracy of the model on the 5835 samples: 88.36332476435304 %
# Accuracy of the model on the 5835 samples: 88.65467009425878 %
# Epoch [48/1000], Step [100/137], Loss: 0.3301
# Accuracy of the model on the 17505 samples: 88.5575549842902 %
# Accuracy of the model on the 5835 samples: 87.98628963153385 %
# Accuracy of the model on the 5835 samples: 88.36332476435304 %
# Epoch [49/1000], Step [100/137], Loss: 0.3082
# Accuracy of the model on the 17505 samples: 89.3116252499286 %
# Accuracy of the model on the 5835 samples: 88.31191088260498 %
# Accuracy of the model on the 5835 samples: 89.03170522707798 %
# Epoch [50/1000], Step [100/137], Loss: 0.3017
# Accuracy of the model on the 17505 samples: 89.27734932876321 %
# Accuracy of the model on the 5835 samples: 88.15766923736075 %
# Accuracy of the model on the 5835 samples: 88.77463581833761 %
# Epoch [51/1000], Step [100/137], Loss: 0.3010
# Accuracy of the model on the 17505 samples: 89.42587832047987 %
# Accuracy of the model on the 5835 samples: 88.31191088260498 %
# Accuracy of the model on the 5835 samples: 88.84318766066838 %
# Epoch [52/1000], Step [100/137], Loss: 0.2844
# Accuracy of the model on the 17505 samples: 89.60297057983433 %
# Accuracy of the model on the 5835 samples: 88.31191088260498 %
# Accuracy of the model on the 5835 samples: 88.77463581833761 %
# Epoch [53/1000], Step [100/137], Loss: 0.2762
# Accuracy of the model on the 17505 samples: 89.07169380177092 %
# Accuracy of the model on the 5835 samples: 88.29477292202228 %
# Accuracy of the model on the 5835 samples: 88.56898029134533 %
# Epoch [54/1000], Step [100/137], Loss: 0.2830
# Accuracy of the model on the 17505 samples: 89.82005141388174 %
# Accuracy of the model on the 5835 samples: 88.67180805484148 %
# Accuracy of the model on the 5835 samples: 89.01456726649529 %
# Epoch [55/1000], Step [100/137], Loss: 0.2949
# Accuracy of the model on the 17505 samples: 89.64295915452728 %
# Accuracy of the model on the 5835 samples: 88.24335904027421 %
# Accuracy of the model on the 5835 samples: 88.87746358183377 %
# Epoch [56/1000], Step [100/137], Loss: 0.2729
# Accuracy of the model on the 17505 samples: 89.69437303627535 %
# Accuracy of the model on the 5835 samples: 88.39760068551843 %
# Accuracy of the model on the 5835 samples: 88.87746358183377 %
# Epoch [57/1000], Step [100/137], Loss: 0.2827
# Accuracy of the model on the 17505 samples: 89.7172236503856 %
# Accuracy of the model on the 5835 samples: 88.96315338474722 %
# Accuracy of the model on the 5835 samples: 89.1688089117395 %
# Epoch [58/1000], Step [100/137], Loss: 0.2853
# Accuracy of the model on the 17505 samples: 89.31733790345615 %
# Accuracy of the model on the 5835 samples: 88.4490145672665 %
# Accuracy of the model on the 5835 samples: 88.65467009425878 %
# Epoch [59/1000], Step [100/137], Loss: 0.2644
# Accuracy of the model on the 17505 samples: 89.63724650099971 %
# Accuracy of the model on the 5835 samples: 88.17480719794345 %
# Accuracy of the model on the 5835 samples: 88.99742930591259 %
# Epoch [60/1000], Step [100/137], Loss: 0.2909
# Accuracy of the model on the 17505 samples: 89.62010854041702 %
# Accuracy of the model on the 5835 samples: 88.53470437017995 %
# Accuracy of the model on the 5835 samples: 88.92887746358183 %
# Epoch [61/1000], Step [100/137], Loss: 0.2842
# Accuracy of the model on the 17505 samples: 89.72293630391317 %
# Accuracy of the model on the 5835 samples: 88.6203941730934 %
# Accuracy of the model on the 5835 samples: 88.75749785775493 %
# Epoch [62/1000], Step [100/137], Loss: 0.2868
# Accuracy of the model on the 17505 samples: 89.75149957155098 %
# Accuracy of the model on the 5835 samples: 88.67180805484148 %
# Accuracy of the model on the 5835 samples: 88.96315338474722 %
# Epoch [63/1000], Step [100/137], Loss: 0.2558
# Accuracy of the model on the 17505 samples: 89.76292487860611 %
# Accuracy of the model on the 5835 samples: 88.56898029134533 %
# Accuracy of the model on the 5835 samples: 89.13453299057412 %
# Epoch [64/1000], Step [100/137], Loss: 0.2996
# Accuracy of the model on the 17505 samples: 89.42587832047987 %
# Accuracy of the model on the 5835 samples: 88.46615252784919 %
# Accuracy of the model on the 5835 samples: 88.67180805484148 %
# Epoch [65/1000], Step [100/137], Loss: 0.2732
# Accuracy of the model on the 17505 samples: 89.94572979148815 %
# Accuracy of the model on the 5835 samples: 89.03170522707798 %
# Accuracy of the model on the 5835 samples: 89.13453299057412 %
# Epoch [66/1000], Step [100/137], Loss: 0.2702
# Accuracy of the model on the 17505 samples: 89.68866038274778 %
# Accuracy of the model on the 5835 samples: 88.50042844901456 %
# Accuracy of the model on the 5835 samples: 88.53470437017995 %
# Epoch [67/1000], Step [100/137], Loss: 0.2718
# Accuracy of the model on the 17505 samples: 89.82576406740931 %
# Accuracy of the model on the 5835 samples: 88.7917737789203 %
# Accuracy of the model on the 5835 samples: 88.99742930591259 %
# Epoch [68/1000], Step [100/137], Loss: 0.2560
# Accuracy of the model on the 17505 samples: 89.94572979148815 %
# Accuracy of the model on the 5835 samples: 88.92887746358183 %
# Accuracy of the model on the 5835 samples: 89.10025706940874 %
# Epoch [69/1000], Step [100/137], Loss: 0.2720
# Accuracy of the model on the 17505 samples: 89.94572979148815 %
# Accuracy of the model on the 5835 samples: 88.68894601542416 %
# Accuracy of the model on the 5835 samples: 89.01456726649529 %
# Epoch [70/1000], Step [100/137], Loss: 0.2542
# Accuracy of the model on the 17505 samples: 90.04855755498428 %
# Accuracy of the model on the 5835 samples: 88.63753213367609 %
# Accuracy of the model on the 5835 samples: 89.01456726649529 %
# Epoch [71/1000], Step [100/137], Loss: 0.2459
# Accuracy of the model on the 17505 samples: 90.19137389317338 %
# Accuracy of the model on the 5835 samples: 88.77463581833761 %
# Accuracy of the model on the 5835 samples: 89.03170522707798 %
# Epoch [72/1000], Step [100/137], Loss: 0.2543
# Accuracy of the model on the 17505 samples: 90.15138531848044 %
# Accuracy of the model on the 5835 samples: 89.23736075407027 %
# Accuracy of the model on the 5835 samples: 89.3401885175664 %
# Epoch [73/1000], Step [100/137], Loss: 0.2556
# Accuracy of the model on the 17505 samples: 90.14567266495287 %
# Accuracy of the model on the 5835 samples: 88.96315338474722 %
# Accuracy of the model on the 5835 samples: 89.04884318766067 %
# Epoch [74/1000], Step [100/137], Loss: 0.2572
# Accuracy of the model on the 17505 samples: 90.08854612967724 %
# Accuracy of the model on the 5835 samples: 88.72322193658954 %
# Accuracy of the model on the 5835 samples: 88.99742930591259 %
# Epoch [75/1000], Step [100/137], Loss: 0.2658
# Accuracy of the model on the 17505 samples: 89.68294772922022 %
# Accuracy of the model on the 5835 samples: 88.65467009425878 %
# Accuracy of the model on the 5835 samples: 88.75749785775493 %
# Epoch [76/1000], Step [100/137], Loss: 0.2637
# Accuracy of the model on the 17505 samples: 89.99143101970866 %
# Accuracy of the model on the 5835 samples: 88.53470437017995 %
# Accuracy of the model on the 5835 samples: 88.99742930591259 %
# Epoch [77/1000], Step [100/137], Loss: 0.2521
# Accuracy of the model on the 17505 samples: 90.23136246786632 %
# Accuracy of the model on the 5835 samples: 89.39160239931448 %
# Accuracy of the model on the 5835 samples: 89.32305055698372 %
# Epoch [78/1000], Step [100/137], Loss: 0.2531
# Accuracy of the model on the 17505 samples: 90.09997143673236 %
# Accuracy of the model on the 5835 samples: 88.96315338474722 %
# Accuracy of the model on the 5835 samples: 88.84318766066838 %
# Epoch [79/1000], Step [100/137], Loss: 0.2635
# Accuracy of the model on the 17505 samples: 89.81433876035419 %
# Accuracy of the model on the 5835 samples: 88.56898029134533 %
# Accuracy of the model on the 5835 samples: 88.89460154241645 %
# Epoch [80/1000], Step [100/137], Loss: 0.2521
# Accuracy of the model on the 17505 samples: 89.9057412167952 %
# Accuracy of the model on the 5835 samples: 88.75749785775493 %
# Accuracy of the model on the 5835 samples: 88.92887746358183 %
# Epoch [81/1000], Step [100/137], Loss: 0.2443
# Accuracy of the model on the 17505 samples: 90.25992573550414 %
# Accuracy of the model on the 5835 samples: 88.58611825192801 %
# Accuracy of the model on the 5835 samples: 88.82604970008569 %
# Epoch [82/1000], Step [100/137], Loss: 0.2612
# Accuracy of the model on the 17505 samples: 89.91145387032276 %
# Accuracy of the model on the 5835 samples: 88.87746358183377 %
# Accuracy of the model on the 5835 samples: 88.94601542416453 %
# Epoch [83/1000], Step [100/137], Loss: 0.2327
# Accuracy of the model on the 17505 samples: 89.89431590974007 %
# Accuracy of the model on the 5835 samples: 88.38046272493574 %
# Accuracy of the model on the 5835 samples: 88.36332476435304 %
# Epoch [84/1000], Step [100/137], Loss: 0.2615
# Accuracy of the model on the 17505 samples: 89.76863753213368 %
# Accuracy of the model on the 5835 samples: 88.48329048843188 %
# Accuracy of the model on the 5835 samples: 88.72322193658954 %
# Epoch [85/1000], Step [100/137], Loss: 0.2461
# Accuracy of the model on the 17505 samples: 90.13424735789775 %
# Accuracy of the model on the 5835 samples: 88.7917737789203 %
# Accuracy of the model on the 5835 samples: 88.68894601542416 %
# Epoch [86/1000], Step [100/137], Loss: 0.2393
# Accuracy of the model on the 17505 samples: 89.91145387032276 %
# Accuracy of the model on the 5835 samples: 88.77463581833761 %
# Accuracy of the model on the 5835 samples: 89.32305055698372 %
# Epoch [87/1000], Step [100/137], Loss: 0.2681
# Accuracy of the model on the 17505 samples: 90.44844330191374 %
# Accuracy of the model on the 5835 samples: 89.15167095115682 %
# Accuracy of the model on the 5835 samples: 89.04884318766067 %
# Epoch [88/1000], Step [100/137], Loss: 0.2683
# Accuracy of the model on the 17505 samples: 90.07140816909454 %
# Accuracy of the model on the 5835 samples: 88.89460154241645 %
# Accuracy of the model on the 5835 samples: 88.77463581833761 %
# Epoch [89/1000], Step [100/137], Loss: 0.2441
# Accuracy of the model on the 17505 samples: 90.1113967437875 %
# Accuracy of the model on the 5835 samples: 89.30591259640103 %
# Accuracy of the model on the 5835 samples: 89.08311910882605 %
# Epoch [90/1000], Step [100/137], Loss: 0.2368
# Accuracy of the model on the 17505 samples: 90.50556983718937 %
# Accuracy of the model on the 5835 samples: 89.10025706940874 %
# Accuracy of the model on the 5835 samples: 89.3401885175664 %
# Epoch [91/1000], Step [100/137], Loss: 0.2619
# Accuracy of the model on the 17505 samples: 90.25992573550414 %
# Accuracy of the model on the 5835 samples: 89.01456726649529 %
# Accuracy of the model on the 5835 samples: 89.39160239931448 %
# Epoch [92/1000], Step [100/137], Loss: 0.2382
# Accuracy of the model on the 17505 samples: 89.98571836618109 %
# Accuracy of the model on the 5835 samples: 88.68894601542416 %
# Accuracy of the model on the 5835 samples: 88.808911739503 %
# Epoch [93/1000], Step [100/137], Loss: 0.2286
# Accuracy of the model on the 17505 samples: 90.4370179948586 %
# Accuracy of the model on the 5835 samples: 89.08311910882605 %
# Accuracy of the model on the 5835 samples: 89.15167095115682 %
# Epoch [94/1000], Step [100/137], Loss: 0.2743
# Accuracy of the model on the 17505 samples: 89.6086832333619 %
# Accuracy of the model on the 5835 samples: 88.68894601542416 %
# Accuracy of the model on the 5835 samples: 88.63753213367609 %
# Epoch [95/1000], Step [100/137], Loss: 0.2635
# Accuracy of the model on the 17505 samples: 90.08283347614967 %
# Accuracy of the model on the 5835 samples: 88.67180805484148 %
# Accuracy of the model on the 5835 samples: 89.03170522707798 %
# Epoch [96/1000], Step [100/137], Loss: 0.2556
# Accuracy of the model on the 17505 samples: 89.98571836618109 %
# Accuracy of the model on the 5835 samples: 88.72322193658954 %
# Accuracy of the model on the 5835 samples: 89.23736075407027 %
# Epoch [97/1000], Step [100/137], Loss: 0.2394
# Accuracy of the model on the 17505 samples: 90.59697229363039 %
# Accuracy of the model on the 5835 samples: 89.04884318766067 %
# Accuracy of the model on the 5835 samples: 89.20308483290488 %
# Epoch [98/1000], Step [100/137], Loss: 0.2719
# Accuracy of the model on the 17505 samples: 89.62010854041702 %
# Accuracy of the model on the 5835 samples: 88.58611825192801 %
# Accuracy of the model on the 5835 samples: 88.15766923736075 %
# Epoch [99/1000], Step [100/137], Loss: 0.3416
# Accuracy of the model on the 17505 samples: 87.31790916880891 %
# Accuracy of the model on the 5835 samples: 87.23221936589546 %
# Accuracy of the model on the 5835 samples: 87.26649528706083 %
# Epoch [100/1000], Step [100/137], Loss: 0.2533
# Accuracy of the model on the 17505 samples: 89.9685804055984 %
# Accuracy of the model on the 5835 samples: 88.84318766066838 %
# Accuracy of the model on the 5835 samples: 88.84318766066838 %
# Epoch [101/1000], Step [100/137], Loss: 0.2475
# Accuracy of the model on the 17505 samples: 90.17423593259069 %
# Accuracy of the model on the 5835 samples: 88.84318766066838 %
# Accuracy of the model on the 5835 samples: 88.86032562125106 %
# Epoch [102/1000], Step [100/137], Loss: 0.2538
# Accuracy of the model on the 17505 samples: 89.88289060268495 %
# Accuracy of the model on the 5835 samples: 89.04884318766067 %
# Accuracy of the model on the 5835 samples: 89.1688089117395 %
# Epoch [103/1000], Step [100/137], Loss: 0.2289
# Accuracy of the model on the 17505 samples: 90.12282205084261 %
# Accuracy of the model on the 5835 samples: 89.11739502999143 %
# Accuracy of the model on the 5835 samples: 89.528706083976 %
# Epoch [104/1000], Step [100/137], Loss: 0.2368
# Accuracy of the model on the 17505 samples: 90.3913167666381 %
# Accuracy of the model on the 5835 samples: 88.91173950299914 %
# Accuracy of the model on the 5835 samples: 88.86032562125106 %
# Epoch [105/1000], Step [100/137], Loss: 0.2170
# Accuracy of the model on the 17505 samples: 90.56840902599258 %
# Accuracy of the model on the 5835 samples: 89.30591259640103 %
# Accuracy of the model on the 5835 samples: 89.1688089117395 %
# Epoch [106/1000], Step [100/137], Loss: 0.2288
# Accuracy of the model on the 17505 samples: 90.52842045129962 %
# Accuracy of the model on the 5835 samples: 89.06598114824335 %
# Accuracy of the model on the 5835 samples: 89.59725792630677 %
# Epoch [107/1000], Step [100/137], Loss: 0.2546
# Accuracy of the model on the 17505 samples: 89.27734932876321 %
# Accuracy of the model on the 5835 samples: 88.89460154241645 %
# Accuracy of the model on the 5835 samples: 88.72322193658954 %
# Epoch [108/1000], Step [100/137], Loss: 0.2559
# Accuracy of the model on the 17505 samples: 90.49414453013425 %
# Accuracy of the model on the 5835 samples: 89.32305055698372 %
# Accuracy of the model on the 5835 samples: 89.11739502999143 %
# Epoch [109/1000], Step [100/137], Loss: 0.2601
# Accuracy of the model on the 17505 samples: 90.34561553841759 %
# Accuracy of the model on the 5835 samples: 89.23736075407027 %
# Accuracy of the model on the 5835 samples: 89.18594687232219 %
# Epoch [110/1000], Step [100/137], Loss: 0.2383
# Accuracy of the model on the 17505 samples: 90.6598114824336 %
# Accuracy of the model on the 5835 samples: 89.28877463581834 %
# Accuracy of the model on the 5835 samples: 89.30591259640103 %
# Epoch [111/1000], Step [100/137], Loss: 0.2327
# Accuracy of the model on the 17505 samples: 90.25992573550414 %
# Accuracy of the model on the 5835 samples: 88.24335904027421 %
# Accuracy of the model on the 5835 samples: 89.10025706940874 %
# Epoch [112/1000], Step [100/137], Loss: 0.2495
# Accuracy of the model on the 17505 samples: 90.51128249071694 %
# Accuracy of the model on the 5835 samples: 88.87746358183377 %
# Accuracy of the model on the 5835 samples: 89.44301628106255 %
# Epoch [113/1000], Step [100/137], Loss: 0.2325
# Accuracy of the model on the 17505 samples: 90.67123678948872 %
# Accuracy of the model on the 5835 samples: 89.51156812339332 %
# Accuracy of the model on the 5835 samples: 89.28877463581834 %
# Epoch [114/1000], Step [100/137], Loss: 0.2600
# Accuracy of the model on the 17505 samples: 90.02570694087403 %
# Accuracy of the model on the 5835 samples: 88.91173950299914 %
# Accuracy of the model on the 5835 samples: 89.3401885175664 %
# Epoch [115/1000], Step [100/137], Loss: 0.2130
# Accuracy of the model on the 17505 samples: 90.63696086832334 %
# Accuracy of the model on the 5835 samples: 89.30591259640103 %
# Accuracy of the model on the 5835 samples: 89.51156812339332 %
# Epoch [116/1000], Step [100/137], Loss: 0.2443
# Accuracy of the model on the 17505 samples: 90.84261639531563 %
# Accuracy of the model on the 5835 samples: 89.46015424164524 %
# Accuracy of the model on the 5835 samples: 89.3401885175664 %
# Epoch [117/1000], Step [100/137], Loss: 0.2165
# Accuracy of the model on the 17505 samples: 90.71122536418166 %
# Accuracy of the model on the 5835 samples: 88.91173950299914 %
# Accuracy of the model on the 5835 samples: 89.15167095115682 %
# Epoch [118/1000], Step [100/137], Loss: 0.2120
# Accuracy of the model on the 17505 samples: 90.09997143673236 %
# Accuracy of the model on the 5835 samples: 88.87746358183377 %
# Accuracy of the model on the 5835 samples: 89.13453299057412 %
# Epoch [119/1000], Step [100/137], Loss: 0.1985
# Accuracy of the model on the 17505 samples: 90.60268494715795 %
# Accuracy of the model on the 5835 samples: 89.10025706940874 %
# Accuracy of the model on the 5835 samples: 89.40874035989717 %
# Epoch [120/1000], Step [100/137], Loss: 0.2156
# Accuracy of the model on the 17505 samples: 90.37989145958298 %
# Accuracy of the model on the 5835 samples: 88.60325621251071 %
# Accuracy of the model on the 5835 samples: 89.25449871465295 %
# Epoch [121/1000], Step [100/137], Loss: 0.2318
# Accuracy of the model on the 17505 samples: 90.73978863181948 %
# Accuracy of the model on the 5835 samples: 89.37446443873179 %
# Accuracy of the model on the 5835 samples: 89.10025706940874 %
# Epoch [122/1000], Step [100/137], Loss: 0.2606
# Accuracy of the model on the 17505 samples: 90.23707512139389 %
# Accuracy of the model on the 5835 samples: 88.65467009425878 %
# Accuracy of the model on the 5835 samples: 89.03170522707798 %
# Epoch [123/1000], Step [100/137], Loss: 0.2549
# Accuracy of the model on the 17505 samples: 89.91145387032276 %
# Accuracy of the model on the 5835 samples: 89.22022279348758 %
# Accuracy of the model on the 5835 samples: 89.3401885175664 %
# Epoch [124/1000], Step [100/137], Loss: 0.2252
# Accuracy of the model on the 17505 samples: 90.35132819194516 %
# Accuracy of the model on the 5835 samples: 88.92887746358183 %
# Accuracy of the model on the 5835 samples: 89.06598114824335 %
# Epoch [125/1000], Step [100/137], Loss: 0.2048
# Accuracy of the model on the 17505 samples: 90.72836332476436 %
# Accuracy of the model on the 5835 samples: 89.22022279348758 %
# Accuracy of the model on the 5835 samples: 89.54584404455869 %
# Epoch [126/1000], Step [100/137], Loss: 0.2182
# Accuracy of the model on the 17505 samples: 90.9111682376464 %
# Accuracy of the model on the 5835 samples: 89.37446443873179 %
# Accuracy of the model on the 5835 samples: 89.13453299057412 %
# Epoch [127/1000], Step [100/137], Loss: 0.2010
# Accuracy of the model on the 17505 samples: 90.60839760068552 %
# Accuracy of the model on the 5835 samples: 89.23736075407027 %
# Accuracy of the model on the 5835 samples: 89.13453299057412 %
# Epoch [128/1000], Step [100/137], Loss: 0.2075
# Accuracy of the model on the 17505 samples: 90.49985718366182 %
# Accuracy of the model on the 5835 samples: 89.18594687232219 %
# Accuracy of the model on the 5835 samples: 89.23736075407027 %
# Epoch [129/1000], Step [100/137], Loss: 0.2005
# Accuracy of the model on the 17505 samples: 90.71693801770923 %
# Accuracy of the model on the 5835 samples: 89.51156812339332 %
# Accuracy of the model on the 5835 samples: 89.3573264781491 %
# Epoch [130/1000], Step [100/137], Loss: 0.2516
# Accuracy of the model on the 17505 samples: 89.71151099685804 %
# Accuracy of the model on the 5835 samples: 88.808911739503 %
# Accuracy of the model on the 5835 samples: 88.9802913453299 %
# Epoch [131/1000], Step [100/137], Loss: 0.1829
# Accuracy of the model on the 17505 samples: 90.5169951442445 %
# Accuracy of the model on the 5835 samples: 89.28877463581834 %
# Accuracy of the model on the 5835 samples: 89.11739502999143 %
# Epoch [132/1000], Step [100/137], Loss: 0.2006
# Accuracy of the model on the 17505 samples: 91.01399600114253 %
# Accuracy of the model on the 5835 samples: 89.78577549271637 %
# Accuracy of the model on the 5835 samples: 89.59725792630677 %
# Epoch [133/1000], Step [100/137], Loss: 0.2325
# Accuracy of the model on the 17505 samples: 90.9397315052842 %
# Accuracy of the model on the 5835 samples: 89.7172236503856 %
# Accuracy of the model on the 5835 samples: 89.18594687232219 %
# Epoch [134/1000], Step [100/137], Loss: 0.2188
# Accuracy of the model on the 17505 samples: 90.04855755498428 %
# Accuracy of the model on the 5835 samples: 88.70608397600685 %
# Accuracy of the model on the 5835 samples: 89.1688089117395 %
# Epoch [135/1000], Step [100/137], Loss: 0.2301
# Accuracy of the model on the 17505 samples: 90.31133961725222 %
# Accuracy of the model on the 5835 samples: 88.92887746358183 %
# Accuracy of the model on the 5835 samples: 88.99742930591259 %
# Epoch [136/1000], Step [100/137], Loss: 0.2230
# Accuracy of the model on the 17505 samples: 90.84832904884318 %
# Accuracy of the model on the 5835 samples: 89.528706083976 %
# Accuracy of the model on the 5835 samples: 89.27163667523564 %
# Epoch [137/1000], Step [100/137], Loss: 0.2140
# Accuracy of the model on the 17505 samples: 91.09397315052843 %
# Accuracy of the model on the 5835 samples: 89.39160239931448 %
# Accuracy of the model on the 5835 samples: 89.51156812339332 %
# Epoch [138/1000], Step [100/137], Loss: 0.2118
# Accuracy of the model on the 17505 samples: 90.47700656955156 %
# Accuracy of the model on the 5835 samples: 88.70608397600685 %
# Accuracy of the model on the 5835 samples: 88.808911739503 %
# Epoch [139/1000], Step [100/137], Loss: 0.1981
# Accuracy of the model on the 17505 samples: 91.1282490716938 %
# Accuracy of the model on the 5835 samples: 89.28877463581834 %
# Accuracy of the model on the 5835 samples: 89.78577549271637 %
# Epoch [140/1000], Step [100/137], Loss: 0.1785
# Accuracy of the model on the 17505 samples: 91.50528420451299 %
# Accuracy of the model on the 5835 samples: 89.78577549271637 %
# Accuracy of the model on the 5835 samples: 89.9057412167952 %
# Epoch [141/1000], Step [100/137], Loss: 0.2282
# Accuracy of the model on the 17505 samples: 90.78548986003999 %
# Accuracy of the model on the 5835 samples: 88.84318766066838 %
# Accuracy of the model on the 5835 samples: 89.15167095115682 %
# Epoch [142/1000], Step [100/137], Loss: 0.1843
# Accuracy of the model on the 17505 samples: 91.12253641816623 %
# Accuracy of the model on the 5835 samples: 89.22022279348758 %
# Accuracy of the model on the 5835 samples: 89.94001713796058 %
# Epoch [143/1000], Step [100/137], Loss: 0.3784
# Accuracy of the model on the 17505 samples: 86.13538988860326 %
# Accuracy of the model on the 5835 samples: 85.5012853470437 %
# Accuracy of the model on the 5835 samples: 86.0325621251071 %
# Epoch [144/1000], Step [100/137], Loss: 0.3795
# Accuracy of the model on the 17505 samples: 86.51813767495001 %
# Accuracy of the model on the 5835 samples: 86.10111396743787 %
# Accuracy of the model on the 5835 samples: 86.08397600685518 %
# Epoch [145/1000], Step [100/137], Loss: 0.3745
# Accuracy of the model on the 17505 samples: 86.94658668951728 %
# Accuracy of the model on the 5835 samples: 86.59811482433591 %
# Accuracy of the model on the 5835 samples: 86.49528706083976 %
# Epoch [146/1000], Step [100/137], Loss: 0.3585
# Accuracy of the model on the 17505 samples: 87.56355327049414 %
# Accuracy of the model on the 5835 samples: 87.11225364181662 %
# Accuracy of the model on the 5835 samples: 87.00942587832049 %
# Epoch [147/1000], Step [100/137], Loss: 0.3712
# Accuracy of the model on the 17505 samples: 87.3350471293916 %
# Accuracy of the model on the 5835 samples: 87.04370179948586 %
# Accuracy of the model on the 5835 samples: 86.94087403598972 %
# Epoch [148/1000], Step [100/137], Loss: 0.3377
# Accuracy of the model on the 17505 samples: 87.86061125392744 %
# Accuracy of the model on the 5835 samples: 87.40359897172236 %
# Accuracy of the model on the 5835 samples: 87.3521850899743 %
# Epoch [149/1000], Step [100/137], Loss: 0.3885
# Accuracy of the model on the 17505 samples: 87.6492430734076 %
# Accuracy of the model on the 5835 samples: 87.64353041988004 %
# Accuracy of the model on the 5835 samples: 87.23221936589546 %
# Epoch [150/1000], Step [100/137], Loss: 0.3578
# Accuracy of the model on the 17505 samples: 87.8834618680377 %
# Accuracy of the model on the 5835 samples: 87.3521850899743 %
# Accuracy of the model on the 5835 samples: 87.31790916880891 %
# Epoch [151/1000], Step [100/137], Loss: 0.3236
# Accuracy of the model on the 17505 samples: 87.42644958583261 %
# Accuracy of the model on the 5835 samples: 86.94087403598972 %
# Accuracy of the model on the 5835 samples: 87.02656383890317 %
# Epoch [152/1000], Step [100/137], Loss: 0.3284
# Accuracy of the model on the 17505 samples: 88.10054270208512 %
# Accuracy of the model on the 5835 samples: 87.57497857754927 %
# Accuracy of the model on the 5835 samples: 87.55784061696659 %
# Epoch [153/1000], Step [100/137], Loss: 0.3335
# Accuracy of the model on the 17505 samples: 88.15766923736075 %
# Accuracy of the model on the 5835 samples: 87.74635818337617 %
# Accuracy of the model on the 5835 samples: 87.55784061696659 %
# Epoch [154/1000], Step [100/137], Loss: 0.3092
# Accuracy of the model on the 17505 samples: 88.30619822907741 %
# Accuracy of the model on the 5835 samples: 87.74635818337617 %
# Accuracy of the model on the 5835 samples: 87.62639245929735 %
# Epoch [155/1000], Step [100/137], Loss: 0.3125
# Accuracy of the model on the 17505 samples: 88.403313339046 %
# Accuracy of the model on the 5835 samples: 87.8834618680377 %
# Accuracy of the model on the 5835 samples: 87.84918594687232 %
# Epoch [156/1000], Step [100/137], Loss: 0.3067
# Accuracy of the model on the 17505 samples: 88.33476149671523 %
# Accuracy of the model on the 5835 samples: 87.84918594687232 %
# Accuracy of the model on the 5835 samples: 87.9005998286204 %
# Epoch [157/1000], Step [100/137], Loss: 0.3089
# Accuracy of the model on the 17505 samples: 88.27192230791202 %
# Accuracy of the model on the 5835 samples: 87.66066838046272 %
# Accuracy of the model on the 5835 samples: 87.74635818337617 %
# Epoch [158/1000], Step [100/137], Loss: 0.2920
# Accuracy of the model on the 17505 samples: 88.33476149671523 %
# Accuracy of the model on the 5835 samples: 87.57497857754927 %
# Accuracy of the model on the 5835 samples: 87.83204798628964 %
# Epoch [159/1000], Step [100/137], Loss: 0.2950
# Accuracy of the model on the 17505 samples: 88.24335904027421 %
# Accuracy of the model on the 5835 samples: 87.69494430162811 %
# Accuracy of the model on the 5835 samples: 87.72922022279349 %
# Epoch [160/1000], Step [100/137], Loss: 0.3094
# Accuracy of the model on the 17505 samples: 88.29477292202228 %
# Accuracy of the model on the 5835 samples: 87.74635818337617 %
# Accuracy of the model on the 5835 samples: 87.9005998286204 %
# Epoch [161/1000], Step [100/137], Loss: 0.2955
# Accuracy of the model on the 17505 samples: 88.19194515852614 %
# Accuracy of the model on the 5835 samples: 87.48928877463582 %
# Accuracy of the model on the 5835 samples: 87.45501285347044 %
# Epoch [162/1000], Step [100/137], Loss: 0.3080
# Accuracy of the model on the 17505 samples: 88.41473864610111 %
# Accuracy of the model on the 5835 samples: 87.72922022279349 %
# Accuracy of the model on the 5835 samples: 87.83204798628964 %
# Epoch [163/1000], Step [100/137], Loss: 0.2935
# Accuracy of the model on the 17505 samples: 88.403313339046 %
# Accuracy of the model on the 5835 samples: 87.64353041988004 %
# Accuracy of the model on the 5835 samples: 88.03770351328193 %
# Epoch [164/1000], Step [100/137], Loss: 0.2948
# Accuracy of the model on the 17505 samples: 88.58040559840046 %
# Accuracy of the model on the 5835 samples: 87.79777206512425 %
# Accuracy of the model on the 5835 samples: 87.86632390745501 %
# Epoch [165/1000], Step [100/137], Loss: 0.2934
# Accuracy of the model on the 17505 samples: 88.60896886603827 %
# Accuracy of the model on the 5835 samples: 87.95201371036846 %
# Accuracy of the model on the 5835 samples: 88.14053127677806 %
# Epoch [166/1000], Step [100/137], Loss: 0.3109
# Accuracy of the model on the 17505 samples: 88.55184233076264 %
# Accuracy of the model on the 5835 samples: 87.79777206512425 %
# Accuracy of the model on the 5835 samples: 87.9005998286204 %
# Epoch [167/1000], Step [100/137], Loss: 0.2939
# Accuracy of the model on the 17505 samples: 88.04341616680948 %
# Accuracy of the model on the 5835 samples: 87.48928877463582 %
# Accuracy of the model on the 5835 samples: 87.50642673521851 %
# Epoch [168/1000], Step [100/137], Loss: 0.3459
# Accuracy of the model on the 17505 samples: 87.78063410454156 %
# Accuracy of the model on the 5835 samples: 87.26649528706083 %
# Accuracy of the model on the 5835 samples: 87.24935732647815 %
# Epoch [169/1000], Step [100/137], Loss: 0.3341
# Accuracy of the model on the 17505 samples: 88.31762353613253 %
# Accuracy of the model on the 5835 samples: 87.67780634104541 %
# Accuracy of the model on the 5835 samples: 87.57497857754927 %
# Epoch [170/1000], Step [100/137], Loss: 0.3152
# Accuracy of the model on the 17505 samples: 88.46043987432162 %
# Accuracy of the model on the 5835 samples: 87.72922022279349 %
# Accuracy of the model on the 5835 samples: 87.84918594687232 %
# Epoch [171/1000], Step [100/137], Loss: 0.3186
# Accuracy of the model on the 17505 samples: 88.39188803199086 %
# Accuracy of the model on the 5835 samples: 87.55784061696659 %
# Accuracy of the model on the 5835 samples: 87.86632390745501 %
# Epoch [172/1000], Step [100/137], Loss: 0.3129
# Accuracy of the model on the 17505 samples: 88.50614110254213 %
# Accuracy of the model on the 5835 samples: 87.57497857754927 %
# Accuracy of the model on the 5835 samples: 87.74635818337617 %
# Epoch [173/1000], Step [100/137], Loss: 0.3448
# Accuracy of the model on the 17505 samples: 88.54041702370752 %
# Accuracy of the model on the 5835 samples: 87.66066838046272 %
# Accuracy of the model on the 5835 samples: 87.76349614395887 %
# Epoch [174/1000], Step [100/137], Loss: 0.3101
# Accuracy of the model on the 17505 samples: 88.64895744073122 %
# Accuracy of the model on the 5835 samples: 87.60925449871465 %
# Accuracy of the model on the 5835 samples: 87.8834618680377 %
# Epoch [175/1000], Step [100/137], Loss: 0.3185
# Accuracy of the model on the 17505 samples: 88.71179662953442 %
# Accuracy of the model on the 5835 samples: 87.83204798628964 %
# Accuracy of the model on the 5835 samples: 88.08911739502999 %
# Epoch [176/1000], Step [100/137], Loss: 0.3121
# Accuracy of the model on the 17505 samples: 88.78034847186518 %
# Accuracy of the model on the 5835 samples: 87.74635818337617 %
# Accuracy of the model on the 5835 samples: 88.10625535561269 %
# Epoch [177/1000], Step [100/137], Loss: 0.3151
# Accuracy of the model on the 17505 samples: 88.6832333618966 %
# Accuracy of the model on the 5835 samples: 87.8834618680377 %
# Accuracy of the model on the 5835 samples: 88.22622107969151 %
# Epoch [178/1000], Step [100/137], Loss: 0.3142
# Accuracy of the model on the 17505 samples: 88.66038274778634 %
# Accuracy of the model on the 5835 samples: 87.83204798628964 %
# Accuracy of the model on the 5835 samples: 88.03770351328193 %
# Epoch [179/1000], Step [100/137], Loss: 0.3060
# Accuracy of the model on the 17505 samples: 88.73464724364467 %
# Accuracy of the model on the 5835 samples: 87.66066838046272 %
# Accuracy of the model on the 5835 samples: 88.00342759211654 %
# Epoch [180/1000], Step [100/137], Loss: 0.3189
# Accuracy of the model on the 17505 samples: 88.5575549842902 %
# Accuracy of the model on the 5835 samples: 87.62639245929735 %
# Accuracy of the model on the 5835 samples: 87.96915167095116 %
# Epoch [181/1000], Step [100/137], Loss: 0.3075
# Accuracy of the model on the 17505 samples: 88.85461296772351 %
# Accuracy of the model on the 5835 samples: 87.91773778920309 %
# Accuracy of the model on the 5835 samples: 88.20908311910883 %
# Epoch [182/1000], Step [100/137], Loss: 0.3072
# Accuracy of the model on the 17505 samples: 89.00314195944016 %
# Accuracy of the model on the 5835 samples: 88.02056555269922 %
# Accuracy of the model on the 5835 samples: 88.38046272493574 %
# Epoch [183/1000], Step [100/137], Loss: 0.3065
# Accuracy of the model on the 17505 samples: 88.95744073121965 %
# Accuracy of the model on the 5835 samples: 87.83204798628964 %
# Accuracy of the model on the 5835 samples: 88.4490145672665 %
# Epoch [184/1000], Step [100/137], Loss: 0.3126
# Accuracy of the model on the 17505 samples: 88.99171665238504 %
# Accuracy of the model on the 5835 samples: 88.20908311910883 %
# Accuracy of the model on the 5835 samples: 88.4318766066838 %
# Epoch [185/1000], Step [100/137], Loss: 0.3326
# Accuracy of the model on the 17505 samples: 88.75178520422736 %
# Accuracy of the model on the 5835 samples: 87.76349614395887 %
# Accuracy of the model on the 5835 samples: 88.24335904027421 %
# Epoch [186/1000], Step [100/137], Loss: 0.2968
# Accuracy of the model on the 17505 samples: 89.14595829762925 %
# Accuracy of the model on the 5835 samples: 87.83204798628964 %
# Accuracy of the model on the 5835 samples: 88.58611825192801 %
# Epoch [187/1000], Step [100/137], Loss: 0.3143
# Accuracy of the model on the 17505 samples: 89.123107683519 %
# Accuracy of the model on the 5835 samples: 87.95201371036846 %
# Accuracy of the model on the 5835 samples: 88.41473864610111 %
# Epoch [188/1000], Step [100/137], Loss: 0.3522
# Accuracy of the model on the 17505 samples: 88.27192230791202 %
# Accuracy of the model on the 5835 samples: 87.47215081405312 %
# Accuracy of the model on the 5835 samples: 87.78063410454156 %
# Epoch [189/1000], Step [100/137], Loss: 0.3077
# Accuracy of the model on the 17505 samples: 88.82033704655812 %
# Accuracy of the model on the 5835 samples: 87.83204798628964 %
# Accuracy of the model on the 5835 samples: 88.4318766066838 %
# Epoch [190/1000], Step [100/137], Loss: 0.3181
# Accuracy of the model on the 17505 samples: 88.78606112539275 %
# Accuracy of the model on the 5835 samples: 87.93487574978577 %
# Accuracy of the model on the 5835 samples: 88.08911739502999 %
# Epoch [191/1000], Step [100/137], Loss: 0.3032
# Accuracy of the model on the 17505 samples: 89.27163667523564 %
# Accuracy of the model on the 5835 samples: 88.12339331619538 %
# Accuracy of the model on the 5835 samples: 88.60325621251071 %
# Epoch [192/1000], Step [100/137], Loss: 0.3008
# Accuracy of the model on the 17505 samples: 89.3401885175664 %
# Accuracy of the model on the 5835 samples: 88.10625535561269 %
# Accuracy of the model on the 5835 samples: 88.67180805484148 %
# Epoch [193/1000], Step [100/137], Loss: 0.2990
# Accuracy of the model on the 17505 samples: 89.20308483290488 %
# Accuracy of the model on the 5835 samples: 88.29477292202228 %
# Accuracy of the model on the 5835 samples: 88.7917737789203 %
# Epoch [194/1000], Step [100/137], Loss: 0.2938
# Accuracy of the model on the 17505 samples: 89.36875178520422 %
# Accuracy of the model on the 5835 samples: 88.50042844901456 %
# Accuracy of the model on the 5835 samples: 88.87746358183377 %
# Epoch [195/1000], Step [100/137], Loss: 0.2989
# Accuracy of the model on the 17505 samples: 89.45444158811767 %
# Accuracy of the model on the 5835 samples: 88.22622107969151 %
# Accuracy of the model on the 5835 samples: 88.7917737789203 %
# Epoch [196/1000], Step [100/137], Loss: 0.3084
# Accuracy of the model on the 17505 samples: 89.70579834333047 %
# Accuracy of the model on the 5835 samples: 88.60325621251071 %
# Accuracy of the model on the 5835 samples: 89.08311910882605 %
# Epoch [197/1000], Step [100/137], Loss: 0.2918
# Accuracy of the model on the 17505 samples: 89.46586689517281 %
# Accuracy of the model on the 5835 samples: 88.60325621251071 %
# Accuracy of the model on the 5835 samples: 88.96315338474722 %
# Epoch [198/1000], Step [100/137], Loss: 0.2987
# Accuracy of the model on the 17505 samples: 89.7172236503856 %
# Accuracy of the model on the 5835 samples: 88.63753213367609 %
# Accuracy of the model on the 5835 samples: 89.08311910882605 %
# Epoch [199/1000], Step [100/137], Loss: 0.2885
# Accuracy of the model on the 17505 samples: 89.54584404455869 %
# Accuracy of the model on the 5835 samples: 88.55184233076264 %
# Accuracy of the model on the 5835 samples: 88.74035989717224 %
# Epoch [200/1000], Step [100/137], Loss: 0.2914
# Accuracy of the model on the 17505 samples: 89.47157954870038 %
# Accuracy of the model on the 5835 samples: 88.38046272493574 %
# Accuracy of the model on the 5835 samples: 88.84318766066838 %
# Epoch [201/1000], Step [100/137], Loss: 0.2821
# Accuracy of the model on the 17505 samples: 90.03713224792916 %
# Accuracy of the model on the 5835 samples: 89.20308483290488 %
# Accuracy of the model on the 5835 samples: 89.13453299057412 %
# Epoch [202/1000], Step [100/137], Loss: 0.2779
# Accuracy of the model on the 17505 samples: 89.84861468151956 %
# Accuracy of the model on the 5835 samples: 88.94601542416453 %
# Accuracy of the model on the 5835 samples: 88.96315338474722 %
# Epoch [203/1000], Step [100/137], Loss: 0.2872
# Accuracy of the model on the 17505 samples: 89.66009711510996 %
# Accuracy of the model on the 5835 samples: 88.7917737789203 %
# Accuracy of the model on the 5835 samples: 88.89460154241645 %
# Epoch [204/1000], Step [100/137], Loss: 0.2831
# ...
# Accuracy of the model on the 5835 samples: 88.51756640959726 %
# Accuracy of the model on the 5835 samples: 88.70608397600685 %
# Epoch [660/1000], Step [100/137], Loss: 0.2193
# Accuracy of the model on the 17505 samples: 89.39160239931448 %
# Accuracy of the model on the 5835 samples: 88.19194515852614 %
# Accuracy of the model on the 5835 samples: 88.51756640959726 %
# Epoch [661/1000], Step [100/137], Loss: 0.2400
# Accuracy of the model on the 17505 samples: 89.63153384747216 %
# Accuracy of the model on the 5835 samples: 88.51756640959726 %
# Accuracy of the model on the 5835 samples: 88.60325621251071 %
# Epoch [662/1000], Step [100/137], Loss: 0.2419
# Accuracy of the model on the 17505 samples: 89.50585546986575 %
# Accuracy of the model on the 5835 samples: 88.4318766066838 %
# Accuracy of the model on the 5835 samples: 88.56898029134533 %
# Epoch [663/1000], Step [100/137], Loss: 0.2377
# Accuracy of the model on the 17505 samples: 89.5629820051414 %
# Accuracy of the model on the 5835 samples: 88.36332476435304 %
# Accuracy of the model on the 5835 samples: 88.70608397600685 %
# Epoch [664/1000], Step [100/137], Loss: 0.2235
# Accuracy of the model on the 17505 samples: 89.55155669808626 %
# Accuracy of the model on the 5835 samples: 88.6203941730934 %
# Accuracy of the model on the 5835 samples: 88.86032562125106 %
# Epoch [665/1000], Step [100/137], Loss: 0.2320
# Accuracy of the model on the 17505 samples: 89.59725792630677 %
# Accuracy of the model on the 5835 samples: 88.58611825192801 %
# Accuracy of the model on the 5835 samples: 88.86032562125106 %
# Epoch [666/1000], Step [100/137], Loss: 0.2145
# Accuracy of the model on the 17505 samples: 89.44301628106255 %
# Accuracy of the model on the 5835 samples: 88.27763496143959 %
# Accuracy of the model on the 5835 samples: 88.84318766066838 %
# Epoch [667/1000], Step [100/137], Loss: 0.2116
# Accuracy of the model on the 17505 samples: 89.66009711510996 %
# Accuracy of the model on the 5835 samples: 88.55184233076264 %
# Accuracy of the model on the 5835 samples: 88.96315338474722 %
# Epoch [668/1000], Step [100/137], Loss: 0.2403
# Accuracy of the model on the 17505 samples: 89.46586689517281 %
# Accuracy of the model on the 5835 samples: 88.27763496143959 %
# Accuracy of the model on the 5835 samples: 88.60325621251071 %
# Epoch [669/1000], Step [100/137], Loss: 0.2360
# Accuracy of the model on the 17505 samples: 89.50585546986575 %
# Accuracy of the model on the 5835 samples: 88.24335904027421 %
# Accuracy of the model on the 5835 samples: 88.89460154241645 %
# Epoch [670/1000], Step [100/137], Loss: 0.2552
# Accuracy of the model on the 17505 samples: 89.30019994287346 %
# Accuracy of the model on the 5835 samples: 88.17480719794345 %
# Accuracy of the model on the 5835 samples: 88.70608397600685 %
# Epoch [671/1000], Step [100/137], Loss: 0.2417
# Accuracy of the model on the 17505 samples: 89.28877463581834 %
# Accuracy of the model on the 5835 samples: 88.05484147386461 %
# Accuracy of the model on the 5835 samples: 88.75749785775493 %
# Epoch [672/1000], Step [100/137], Loss: 0.2513
# Accuracy of the model on the 17505 samples: 89.26592402170809 %
# Accuracy of the model on the 5835 samples: 87.8834618680377 %
# Accuracy of the model on the 5835 samples: 88.65467009425878 %
# Epoch [673/1000], Step [100/137], Loss: 0.2237
# Accuracy of the model on the 17505 samples: 89.45444158811767 %
# Accuracy of the model on the 5835 samples: 88.2604970008569 %
# Accuracy of the model on the 5835 samples: 88.72322193658954 %
# Epoch [674/1000], Step [100/137], Loss: 0.2260
# Accuracy of the model on the 17505 samples: 89.74578691802343 %
# Accuracy of the model on the 5835 samples: 88.82604970008569 %
# Accuracy of the model on the 5835 samples: 89.20308483290488 %
# Epoch [675/1000], Step [100/137], Loss: 0.2423
# Accuracy of the model on the 17505 samples: 89.53441873750357 %
# Accuracy of the model on the 5835 samples: 88.31191088260498 %
# Accuracy of the model on the 5835 samples: 88.87746358183377 %
# Epoch [676/1000], Step [100/137], Loss: 0.2553
# Accuracy of the model on the 17505 samples: 89.43730362753499 %
# Accuracy of the model on the 5835 samples: 88.29477292202228 %
# Accuracy of the model on the 5835 samples: 88.808911739503 %
# Epoch [677/1000], Step [100/137], Loss: 0.2304
# Accuracy of the model on the 17505 samples: 89.9228791773779 %
# Accuracy of the model on the 5835 samples: 88.63753213367609 %
# Accuracy of the model on the 5835 samples: 89.04884318766067 %
# Epoch [678/1000], Step [100/137], Loss: 0.2274
# Accuracy of the model on the 17505 samples: 89.91145387032276 %
# Accuracy of the model on the 5835 samples: 88.84318766066838 %
# Accuracy of the model on the 5835 samples: 89.15167095115682 %
# Epoch [679/1000], Step [100/137], Loss: 0.2106
# Accuracy of the model on the 17505 samples: 90.1399600114253 %
# Accuracy of the model on the 5835 samples: 89.15167095115682 %
# Accuracy of the model on the 5835 samples: 89.42587832047987 %
# Epoch [680/1000], Step [100/137], Loss: 0.2261
# Accuracy of the model on the 17505 samples: 89.83718937446444 %
# Accuracy of the model on the 5835 samples: 88.56898029134533 %
# Accuracy of the model on the 5835 samples: 89.15167095115682 %
# Epoch [681/1000], Step [100/137], Loss: 0.2268
# Accuracy of the model on the 17505 samples: 89.94572979148815 %
# Accuracy of the model on the 5835 samples: 88.84318766066838 %
# Accuracy of the model on the 5835 samples: 89.58011996572408 %
# Epoch [682/1000], Step [100/137], Loss: 0.2237
# Accuracy of the model on the 17505 samples: 89.94001713796058 %
# Accuracy of the model on the 5835 samples: 88.94601542416453 %
# Accuracy of the model on the 5835 samples: 89.15167095115682 %
# Epoch [683/1000], Step [100/137], Loss: 0.2199
# Accuracy of the model on the 17505 samples: 90.157097972008 %
# Accuracy of the model on the 5835 samples: 88.82604970008569 %
# Accuracy of the model on the 5835 samples: 89.39160239931448 %
# Epoch [684/1000], Step [100/137], Loss: 0.2299
# Accuracy of the model on the 17505 samples: 90.09997143673236 %
# Accuracy of the model on the 5835 samples: 88.89460154241645 %
# Accuracy of the model on the 5835 samples: 89.1688089117395 %
# Epoch [685/1000], Step [100/137], Loss: 0.2239
# Accuracy of the model on the 17505 samples: 89.64867180805484 %
# Accuracy of the model on the 5835 samples: 88.46615252784919 %
# Accuracy of the model on the 5835 samples: 88.77463581833761 %
# Epoch [686/1000], Step [100/137], Loss: 0.2398
# Accuracy of the model on the 17505 samples: 89.87146529562982 %
# Accuracy of the model on the 5835 samples: 88.74035989717224 %
# Accuracy of the model on the 5835 samples: 89.44301628106255 %
# Epoch [687/1000], Step [100/137], Loss: 0.2312
# Accuracy of the model on the 17505 samples: 89.82005141388174 %
# Accuracy of the model on the 5835 samples: 88.89460154241645 %
# Accuracy of the model on the 5835 samples: 89.25449871465295 %
# Epoch [688/1000], Step [100/137], Loss: 0.2146
# Accuracy of the model on the 17505 samples: 89.97429305912597 %
# Accuracy of the model on the 5835 samples: 88.99742930591259 %
# Accuracy of the model on the 5835 samples: 89.5629820051414 %
# Epoch [689/1000], Step [100/137], Loss: 0.2298
# Accuracy of the model on the 17505 samples: 89.76292487860611 %
# Accuracy of the model on the 5835 samples: 88.86032562125106 %
# Accuracy of the model on the 5835 samples: 89.22022279348758 %
# Epoch [690/1000], Step [100/137], Loss: 0.2246
# Accuracy of the model on the 17505 samples: 90.17994858611826 %
# Accuracy of the model on the 5835 samples: 89.03170522707798 %
# Accuracy of the model on the 5835 samples: 89.5629820051414 %
# Epoch [691/1000], Step [100/137], Loss: 0.2295
# Accuracy of the model on the 17505 samples: 89.87717794915739 %
# Accuracy of the model on the 5835 samples: 88.63753213367609 %
# Accuracy of the model on the 5835 samples: 88.96315338474722 %
# Epoch [692/1000], Step [100/137], Loss: 0.2063
# Accuracy of the model on the 17505 samples: 90.55698371893745 %
# Accuracy of the model on the 5835 samples: 89.51156812339332 %
# Accuracy of the model on the 5835 samples: 89.76863753213368 %
# Epoch [693/1000], Step [100/137], Loss: 0.2591
# Accuracy of the model on the 17505 samples: 89.76292487860611 %
# Accuracy of the model on the 5835 samples: 88.63753213367609 %
# Accuracy of the model on the 5835 samples: 89.10025706940874 %
# Epoch [694/1000], Step [100/137], Loss: 0.1966
# Accuracy of the model on the 17505 samples: 90.52842045129962 %
# Accuracy of the model on the 5835 samples: 89.40874035989717 %
# Accuracy of the model on the 5835 samples: 89.63153384747216 %
# Epoch [695/1000], Step [100/137], Loss: 0.2144
# Accuracy of the model on the 17505 samples: 90.43130534133105 %
# Accuracy of the model on the 5835 samples: 89.3401885175664 %
# Accuracy of the model on the 5835 samples: 89.39160239931448 %
# Epoch [696/1000], Step [100/137], Loss: 0.2099
# Accuracy of the model on the 17505 samples: 90.59125964010283 %
# Accuracy of the model on the 5835 samples: 89.51156812339332 %
# Accuracy of the model on the 5835 samples: 89.70008568980292 %
# Epoch [697/1000], Step [100/137], Loss: 0.2587
# Accuracy of the model on the 17505 samples: 89.70579834333047 %
# Accuracy of the model on the 5835 samples: 88.34618680377035 %
# Accuracy of the model on the 5835 samples: 89.25449871465295 %
# Epoch [698/1000], Step [100/137], Loss: 0.2083
# Accuracy of the model on the 17505 samples: 90.00856898029134 %
# Accuracy of the model on the 5835 samples: 88.82604970008569 %
# Accuracy of the model on the 5835 samples: 89.37446443873179 %
# Epoch [699/1000], Step [100/137], Loss: 0.1982
# Accuracy of the model on the 17505 samples: 90.51128249071694 %
# Accuracy of the model on the 5835 samples: 89.68294772922022 %
# Accuracy of the model on the 5835 samples: 89.75149957155098 %
# Epoch [700/1000], Step [100/137], Loss: 0.2034
# Accuracy of the model on the 17505 samples: 90.35132819194516 %
# Accuracy of the model on the 5835 samples: 89.20308483290488 %
# Accuracy of the model on the 5835 samples: 89.3401885175664 %
# Epoch [701/1000], Step [100/137], Loss: 0.1944
# Accuracy of the model on the 17505 samples: 90.2827763496144 %
# Accuracy of the model on the 5835 samples: 88.99742930591259 %
# Accuracy of the model on the 5835 samples: 89.28877463581834 %
# Epoch [702/1000], Step [100/137], Loss: 0.1997
# Accuracy of the model on the 17505 samples: 90.59697229363039 %
# Accuracy of the model on the 5835 samples: 89.20308483290488 %
# Accuracy of the model on the 5835 samples: 89.59725792630677 %
# Epoch [703/1000], Step [100/137], Loss: 0.2089
# Accuracy of the model on the 17505 samples: 90.71693801770923 %
# Accuracy of the model on the 5835 samples: 89.528706083976 %
# Accuracy of the model on the 5835 samples: 89.76863753213368 %
# Epoch [704/1000], Step [100/137], Loss: 0.2093
# Accuracy of the model on the 17505 samples: 90.35132819194516 %
# Accuracy of the model on the 5835 samples: 89.20308483290488 %
# Accuracy of the model on the 5835 samples: 89.44301628106255 %
# Epoch [705/1000], Step [100/137], Loss: 0.1950
# Accuracy of the model on the 17505 samples: 90.4084547272208 %
# Accuracy of the model on the 5835 samples: 89.1688089117395 %
# Accuracy of the model on the 5835 samples: 89.28877463581834 %
# Epoch [706/1000], Step [100/137], Loss: 0.2132
# Accuracy of the model on the 17505 samples: 90.38560411311055 %
# Accuracy of the model on the 5835 samples: 89.47729220222793 %
# Accuracy of the model on the 5835 samples: 89.42587832047987 %
# Epoch [707/1000], Step [100/137], Loss: 0.2115
# Accuracy of the model on the 17505 samples: 90.44273064838617 %
# Accuracy of the model on the 5835 samples: 89.3401885175664 %
# Accuracy of the model on the 5835 samples: 89.39160239931448 %
# Epoch [708/1000], Step [100/137], Loss: 0.1874
# Accuracy of the model on the 17505 samples: 90.71122536418166 %
# Accuracy of the model on the 5835 samples: 89.47729220222793 %
# Accuracy of the model on the 5835 samples: 89.9057412167952 %
# Epoch [709/1000], Step [100/137], Loss: 0.2167
# Accuracy of the model on the 17505 samples: 90.37989145958298 %
# Accuracy of the model on the 5835 samples: 88.82604970008569 %
# Accuracy of the model on the 5835 samples: 88.94601542416453 %
# Epoch [710/1000], Step [100/137], Loss: 0.2090
# Accuracy of the model on the 17505 samples: 90.63124821479578 %
# Accuracy of the model on the 5835 samples: 89.28877463581834 %
# Accuracy of the model on the 5835 samples: 89.47729220222793 %
# Epoch [711/1000], Step [100/137], Loss: 0.2153
# Accuracy of the model on the 17505 samples: 90.08854612967724 %
# Accuracy of the model on the 5835 samples: 88.75749785775493 %
# Accuracy of the model on the 5835 samples: 89.18594687232219 %
# Epoch [712/1000], Step [100/137], Loss: 0.1924
# Accuracy of the model on the 17505 samples: 90.67123678948872 %
# Accuracy of the model on the 5835 samples: 89.44301628106255 %
# Accuracy of the model on the 5835 samples: 89.78577549271637 %
# Epoch [713/1000], Step [100/137], Loss: 0.1944
# Accuracy of the model on the 17505 samples: 90.64838617537846 %
# Accuracy of the model on the 5835 samples: 89.1688089117395 %
# Accuracy of the model on the 5835 samples: 89.32305055698372 %
# Epoch [714/1000], Step [100/137], Loss: 0.1953
# Accuracy of the model on the 17505 samples: 90.68266209654385 %
# Accuracy of the model on the 5835 samples: 89.49443016281063 %
# Accuracy of the model on the 5835 samples: 89.40874035989717 %
# Epoch [715/1000], Step [100/137], Loss: 0.2111
# Accuracy of the model on the 17505 samples: 90.46558126249643 %
# Accuracy of the model on the 5835 samples: 89.18594687232219 %
# Accuracy of the model on the 5835 samples: 89.08311910882605 %
# Epoch [716/1000], Step [100/137], Loss: 0.2266
# Accuracy of the model on the 17505 samples: 90.16852327906312 %
# Accuracy of the model on the 5835 samples: 88.99742930591259 %
# Accuracy of the model on the 5835 samples: 89.1688089117395 %
# Epoch [717/1000], Step [100/137], Loss: 0.2125
# Accuracy of the model on the 17505 samples: 90.471293916024 %
# Accuracy of the model on the 5835 samples: 89.10025706940874 %
# Accuracy of the model on the 5835 samples: 89.15167095115682 %
# Epoch [718/1000], Step [100/137], Loss: 0.2114
# Accuracy of the model on the 17505 samples: 90.62553556126821 %
# Accuracy of the model on the 5835 samples: 89.3401885175664 %
# Accuracy of the model on the 5835 samples: 89.28877463581834 %
# Epoch [719/1000], Step [100/137], Loss: 0.1943
# Accuracy of the model on the 17505 samples: 90.59125964010283 %
# Accuracy of the model on the 5835 samples: 89.11739502999143 %
# Accuracy of the model on the 5835 samples: 89.27163667523564 %
# Epoch [720/1000], Step [100/137], Loss: 0.1831
# Accuracy of the model on the 17505 samples: 90.97400742644959 %
# Accuracy of the model on the 5835 samples: 89.61439588688945 %
# Accuracy of the model on the 5835 samples: 89.70008568980292 %
# Epoch [721/1000], Step [100/137], Loss: 0.1918
# Accuracy of the model on the 17505 samples: 90.72265067123679 %
# Accuracy of the model on the 5835 samples: 89.1688089117395 %
# Accuracy of the model on the 5835 samples: 89.47729220222793 %
# Epoch [722/1000], Step [100/137], Loss: 0.2347
# Accuracy of the model on the 17505 samples: 89.9228791773779 %
# Accuracy of the model on the 5835 samples: 88.39760068551843 %
# Accuracy of the model on the 5835 samples: 88.74035989717224 %
# Epoch [723/1000], Step [100/137], Loss: 0.1981
# Accuracy of the model on the 17505 samples: 90.83690374178806 %
# Accuracy of the model on the 5835 samples: 89.7172236503856 %
# Accuracy of the model on the 5835 samples: 89.18594687232219 %
# Epoch [724/1000], Step [100/137], Loss: 0.2209
# Accuracy of the model on the 17505 samples: 90.6883747500714 %
# Accuracy of the model on the 5835 samples: 89.22022279348758 %
# Accuracy of the model on the 5835 samples: 89.42587832047987 %
# Epoch [725/1000], Step [100/137], Loss: 0.2067
# Accuracy of the model on the 17505 samples: 90.56840902599258 %
# Accuracy of the model on the 5835 samples: 89.3401885175664 %
# Accuracy of the model on the 5835 samples: 89.39160239931448 %
# Epoch [726/1000], Step [100/137], Loss: 0.1982
# Accuracy of the model on the 17505 samples: 90.96258211939445 %
# Accuracy of the model on the 5835 samples: 89.528706083976 %
# Accuracy of the model on the 5835 samples: 89.70008568980292 %

# %%
# Test the model
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in val_iterator:
        images = images.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print(f'Val Accuracy of the model on the {len(y_val)} val images: {100 * correct / total} %') 
            
# Test the model
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_iterator:
        images = images.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print(f'Test Accuracy of the model on the {len(y_test)} test images: {100 * correct / total} %')

# %%
print(model)
# Out:
# RNN(
#   (lstm): LSTM(28, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
from torchviz import make_dot

dum_input = torch.ones(1,28,28).to(device)
a = model(dum_input)
make_dot(a, params=dict(model.named_parameters())).render(f"{save_dir}viz/lstm-{num_epochs}epochs-{num_layers}layers-{hidden_size}hidden",format="png")
# Out:
# '/home/hwixley/Documents/4th-Year/Honours-Project/localhost-data-preprocessing/ml-models/polar-lag0/viz/lstm-20epochs-2layers-128hidden.png'

# %%
SEED = 1234

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
class VGG(nn.Module):
    def __init__(self, features, output_dim):
        super().__init__()

        self.features = features

        self.avgpool = nn.AdaptiveAvgPool2d(7)

        self.classifier = nn.Sequential(
            nn.Linear(512 * 7 * 7, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(4096, output_dim),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        h = x.view(x.shape[0], -1)
        x = self.classifier(h)
        return x, h

# %%
vgg11_config = [6, 'M', 12, 'M', 24, 24, 'M']#[64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M']

vgg13_config = [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512,
                512, 'M']

vgg16_config = [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512,
                'M', 512, 512, 512, 'M']

vgg19_config = [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512,
                512, 512, 'M', 512, 512, 512, 512, 'M']

# %%
def get_vgg_layers(config, batch_norm):

    layers = []
    in_channels = 3

    for c in config:
        assert c == 'M' or isinstance(c, int)
        if c == 'M':
            layers += [nn.MaxPool2d(kernel_size=2)]
        else:
            conv2d = nn.Conv2d(in_channels, c, kernel_size=3, padding=1)
            if batch_norm:
                layers += [conv2d, nn.BatchNorm2d(c), nn.ReLU(inplace=True)]
            else:
                layers += [conv2d, nn.ReLU(inplace=True)]
            in_channels = c

    return nn.Sequential(*layers)

# %%
vgg11_layers = get_vgg_layers(vgg11_config, batch_norm=True)

# %%
OUTPUT_DIM = 2

model = VGG(vgg11_layers, OUTPUT_DIM)

print(model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(6, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace=True)
#     (11): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU(inplace=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=7)
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ## TRAINING

# %%
START_LR = 1e-7

optimizer = optim.Adam(model.parameters(), lr=START_LR)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

criterion = nn.CrossEntropyLoss()

model = model.to(device)
criterion = criterion.to(device)

# %%
class LRFinder:
    def __init__(self, model, optimizer, criterion, device):

        self.optimizer = optimizer
        self.model = model
        self.criterion = criterion
        self.device = device

        torch.save(model.state_dict(), 'init_params.pt')

    def range_test(self, iterator, end_lr=10, num_iter=100,
                   smooth_f=0.05, diverge_th=5):

        lrs = []
        losses = []
        best_loss = float('inf')

        lr_scheduler = ExponentialLR(self.optimizer, end_lr, num_iter)

        iterator = IteratorWrapper(iterator)

        for iteration in range(num_iter):

            loss = self._train_batch(iterator)

            lrs.append(lr_scheduler.get_last_lr()[0])

            # update lr
            lr_scheduler.step()

            if iteration > 0:
                loss = smooth_f * loss + (1 - smooth_f) * losses[-1]

            if loss < best_loss:
                best_loss = loss

            losses.append(loss)

            if loss > diverge_th * best_loss:
                print("Stopping early, the loss has diverged")
                break

        # reset model to initial parameters
        model.load_state_dict(torch.load('init_params.pt'))

        return lrs, losses

    def _train_batch(self, iterator):

        self.model.train()

        self.optimizer.zero_grad()

        x, y = iterator.get_batch()

        x = x.to(self.device)
        y = y.to(self.device)

        y_pred, _ = self.model(x)

        loss = self.criterion(y_pred, y)

        loss.backward()

        self.optimizer.step()

        return loss.item()


class ExponentialLR(_LRScheduler):
    def __init__(self, optimizer, end_lr, num_iter, last_epoch=-1):
        self.end_lr = end_lr
        self.num_iter = num_iter
        super(ExponentialLR, self).__init__(optimizer, last_epoch)

    def get_lr(self):
        curr_iter = self.last_epoch
        r = curr_iter / self.num_iter
        return [base_lr * (self.end_lr / base_lr) ** r for base_lr in
                self.base_lrs]


class IteratorWrapper:
    def __init__(self, iterator):
        self.iterator = iterator
        self._iterator = iter(iterator)

    def __next__(self):
        try:
            inputs, labels = next(self._iterator)
        except StopIteration:
            self._iterator = iter(self.iterator)
            inputs, labels, *_ = next(self._iterator)

        return inputs, labels

    def get_batch(self):
        return next(self)

# %%
END_LR = 10
NUM_ITER = 100

lr_finder = LRFinder(model, optimizer, criterion, device)
lrs, losses = lr_finder.range_test(train_iterator, END_LR, NUM_ITER)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_20757/2487619677.py in <module>
#       3
#       4 lr_finder = LRFinder(model, optimizer, criterion, device)
# ----> 5 lrs, losses = lr_finder.range_test(train_iterator, END_LR, NUM_ITER)
#
# /tmp/ipykernel_20757/3766690282.py in range_test(self, iterator, end_lr, num_iter, smooth_f, diverge_th)
#      22         for iteration in range(num_iter):
#      23
# ---> 24             loss = self._train_batch(iterator)
#      25
#      26             lrs.append(lr_scheduler.get_last_lr()[0])
#
# /tmp/ipykernel_20757/3766690282.py in _train_batch(self, iterator)
#      57         y = y.to(self.device)
#      58
# ---> 59         y_pred, _ = self.model(x)
#      60
#      61         loss = self.criterion(y_pred, y)
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /tmp/ipykernel_20757/1629760926.py in forward(self, x)
#      18
#      19     def forward(self, x):
# ---> 20         x = self.features(x)
#      21         x = self.avgpool(x)
#      22         h = x.view(x.shape[0], -1)
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/modules/pooling.py in forward(self, input)
#     160
#     161     def forward(self, input: Tensor):
# --> 162         return F.max_pool2d(input, self.kernel_size, self.stride,
#     163                             self.padding, self.dilation, self.ceil_mode,
#     164                             self.return_indices)
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/_jit_internal.py in fn(*args, **kwargs)
#     420             return if_true(*args, **kwargs)
#     421         else:
# --> 422             return if_false(*args, **kwargs)
#     423
#     424     if if_true.__doc__ is None and if_false.__doc__ is not None:
#
# ~/miniconda3/envs/ai/lib/python3.9/site-packages/torch/nn/functional.py in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     781     if stride is None:
#     782         stride = torch.jit.annotate(List[int], [])
# --> 783     return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#     784
#     785
#
# RuntimeError: Given input size: (12x1x1). Calculated output size: (12x0x0). Output size is too small
